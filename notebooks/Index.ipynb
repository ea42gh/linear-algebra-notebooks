# %% [markdown]
# <div style="float:center;width:100%;text-align: center;"><strong style="height:60px;color:darkred;font-size:40px;">Notebook Index</strong></div>

# %% [markdown]
# # Overview

# %% [markdown]
# * The directory Notes is an [**Obsidian Vault**](https://obsidian.md/) with pages listing the contents of the notebooks,<br>
# $\qquad$ to provide a starting point for notetaking.<br>
# $\qquad$ A version of the [**LAcompanion text**](../Notes/Linear_Algebra/LAcompanion.pdf) is in the vault.
#
# * Numbered notebooks using python and/or Julia were used to produce **lecture videos** available on a [**youtube channel**](https://www.youtube.com/playlist?list=PLBDUlnmEqyXD_llq6wETUqRkJGRiu8wFU) <br>
# $\qquad$ The somewhat idiosyncratic ordering of topics reflects the textbook used for the course.
#
# * Unnumbered notebooks are work at various stages of completion:<br>
# $\qquad$ Most are ready for a video.

# %% [markdown]
# # 1. Scalars, Vectors, Matrices: Definitions and Operations

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [01_ScalarsVectorsMatrices.ipynb](01_ScalarsVectorsMatrices.ipynb) | Introduces basic concepts of scalars, vectors, and matrices in linear algebra.|
# | [02_AddScalarMultDotprod.ipynb](02_AddScalarMultDotprod.ipynb) | Explores scalar addition, multiplication, and the dot product of vectors.|
# | [03_MatrixMultiplication.ipynb](03_MatrixMultiplication.ipynb) | Explains matrix multiplication and its properties.|
# | [04_MatrixAlgebra.ipynb](04_MatrixAlgebra.ipynb) | Covers key matrix operations such as addition, multiplication, and transposition.|
# | [MatrixMultApplication_GraphTheory.ipynb](MatrixMultApplication_GraphTheory.ipynb) | Applies matrix multiplication to graph theory problems.|
# </div>

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [01_ScalarsVectorsMatrices.ipynb](01_ScalarsVectorsMatrices.ipynb) | Introduces basic concepts of scalars, vectors, and matrices in linear algebra.|
# | [02_AddScalarMultDotprod.ipynb](02_AddScalarMultDotprod.ipynb) | Explores scalar addition, multiplication, and the dot product of vectors.|
# | [03_MatrixMultiplication.ipynb](03_MatrixMultiplication.ipynb) | Explains matrix multiplication and its properties.|
# | [04_MatrixAlgebra.ipynb](04_MatrixAlgebra.ipynb) | Covers key matrix operations such as addition, multiplication, and transposition.|
# | [MatrixMultApplication_GraphTheory.ipynb](MatrixMultApplication_GraphTheory.ipynb) | Applies matrix multiplication to graph theory problems.|
# </div>

# %% [markdown]
# # 2. Gaussian Elimination, Gauss Jordan Elimination, Special Cases

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [05_RowEchelonForm_Systems.ipynb](05_RowEchelonForm_Systems.ipynb) | Explains row echelon form and its application in solving linear systems.|
# | [06_GE_Systems.ipynb](06_GE_Systems.ipynb) | Demonstrates Gaussian elimination for solving linear systems.|
# | [07_GE_Systems.ipynb](07_GE_Systems.ipynb) | Further examples and exercises on Gaussian elimination.|
# | [PDE_example.ipynb](PDE_example.ipynb) | Solves partial differential equations using linear algebra methods.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [11_Inverses.ipynb](11_Inverses.ipynb) | Explores matrix inverses and methods for computing them.|
# | [12_LU_decomposition.ipynb](12_LU_decomposition.ipynb) | Explains LU decomposition and its use in solving linear systems.|
# | [LU.ipynb](LU.ipynb) | Covers LU decomposition for efficient matrix factorization.|
# | [HillsCypher.ipynb](HillsCypher.ipynb) | Uses matrix operations to explore the Hill cipher, an encryption method.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [CR_Decomposition.ipynb](CR_Decomposition.ipynb) | Covers the CR decomposition, a matrix factorization technique.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [CholeskyDecomposition.ipynb](CholeskyDecomposition.ipynb) | Discusses Cholesky decomposition for positive definite matrices.|
# | [CholeskyDecompositionExample.ipynb](CholeskyDecompositionExample.ipynb) | Provides an example of Cholesky decomposition applied to a matrix.|
# | [UpdateOfMatrixInverse.ipynb](UpdateOfMatrixInverse.ipynb) | Discusses methods for updating the inverse of a matrix.|
# </div>

# %% [markdown]
# # 3. Rowechelon Forms using Givens or Householder Transformations

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [GivensRotations.ipynb](GivensRotations.ipynb) | Explains the use of Givens rotations for orthogonal transformations.|
# | [HouseholderReflections.ipynb](HouseholderReflections.ipynb) | Introduces Householder reflections, a technique for orthogonalizing vectors.|
# </div>

# %% [markdown]
# # 4. Bases, Spaces, Fundamental Theorem

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [08_LinearIndependence.ipynb](08_LinearIndependence.ipynb) | Defines linear independence and its role in vector spaces.|
# | [LinearIndependence.ipynb](LinearIndependence.ipynb) | Re-visits the concept of linear independence in vector spaces.|
# | [15_VectorSpaces.ipynb](15_VectorSpaces.ipynb) | Introduces vector spaces and their axioms.|
# | [16_Basis.ipynb](16_Basis.ipynb) | Explains the concept of a basis for a vector space.|
# | [CoordinateSystems.ipynb](CoordinateSystems.ipynb) | Discusses different coordinate systems and their transformations in linear algebra.|
# | [CxFundamentalTheorem.ipynb](CxFundamentalTheorem.ipynb) | Explains the fundamental theorem of algebra for complex matrices.|
# </div>

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# |      |      |
# | ---- | ---- |
# | [ThreeBasesExample.ipynb](ThreeBasesExample.ipynb) | Provides an example of a vector space with three bases.|
# | [FourierMatrix.ipynb](FourierMatrix.ipynb) | Analyzes the Fourier matrix and its role in Fourier transforms.|
# | [LightsOut.ipynb](LightsOut.ipynb) | Solves the LightsOut puzzle using linear algebra techniques.|
# </div>

# %% [markdown]
# # 5. Linear Transformations

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [09_LinearTransformations.ipynb](09_LinearTransformations.ipynb) | Introduces linear transformations and their matrix representations.|
# | [10a_LinearTx_Examples.ipynb](10a_LinearTx_Examples.ipynb) | Provides examples of linear transformations with visualizations.|
# | [10b_LinearTx_SpaceOfFunctions_Examples.ipynb](10b_LinearTx_SpaceOfFunctions_Examples.ipynb) | Discusses linear transformations in the context of function spaces.|
# | [10c_GeoGebra.ipynb](10c_GeoGebra.ipynb) | Uses GeoGebra to visualize geometric properties of linear transformations.|
# | [10d_LinearTx_Examples.ipynb](10d_LinearTx_Examples.ipynb) | More examples of linear transformations and their effects.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [NonLinearTransformations.ipynb](NonLinearTransformations.ipynb) | Explores nonlinear transformations and their relation to linear algebra.|
# | [Projections.ipynb](Projections.ipynb) | Discusses projection matrices and their role in linear transformations.|
# </div>

# %% [markdown]
# # 6. Length, Areas, Determinants, Orthogonality

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [20_LengthOrthogonality.ipynb](20_LengthOrthogonality.ipynb) | Explains the concepts of length and orthogonality in vector spaces.|
# | [21_ProjectionsGramSchmidt.ipynb](21_ProjectionsGramSchmidt.ipynb) | Describes projections and the Gram-Schmidt process for orthogonalizing vectors.|
# | [Modified_GramSchmidt.ipynb](ModifiedGramSchmidt.ipynb) | Reformulated Gram Schmidt Procedure for better numerical behavior |
# | [21a_LinearTx_NormalEquations.ipynb](21a_LinearTx_NormalEquations.ipynb) | Explores linear transformations through the lens of normal equations.|
# | [NormalEquation_3_ways.ipynb](NormalEquation_3_ways.ipynb) | Solving the normal equation directly, using QR or using the pseudo inverse |
# | [MeanAndStdProjections.ipynb](MeanAndStdProjections.ipynb) | Discusses projection matrices in the context of mean and standard deviation.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [LeastMeanSquares.ipynb](LeastMeanSquares.ipynb) | Introduces least mean squares (LMS) for solving overdetermined systems.|
# | [Regression.ipynb](Regression.ipynb) | Introduces linear regression and its formulation using matrices.|
# | [Orthogonal_Decomposition_Example.ipynb](Orthogonal_Decomposition_Example.ipynb) | Provides an example of orthogonal decomposition of a vector space.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [22_QR_Decomposition.ipynb](22_QR_Decomposition.ipynb) | Discusses QR decomposition and its applications in solving linear systems.|
# | [23_MetricSpaces.ipynb](23_MetricSpaces.ipynb) | Introduces metric spaces and their connection to linear algebra.|
# | [Orthogonality.ipynb](Orthogonality.ipynb) | Discusses the concept of orthogonality in vector spaces and its applications.|
# | [QR_orthogonal_polynomials.ipynb](QR_orthogonal_polynomials.ipynb) | Applies QR decomposition to orthogonal polynomials.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [13_WedgeProduct.ipynb](13_WedgeProduct.ipynb) | Discusses the wedge product and its applications in higher-dimensional vector spaces.|
# | [14_Determinants.ipynb](14_Determinants.ipynb) | Defines determinants and their properties in linear algebra.|
# </div>

# %% [markdown]
# # 7. Eigendecompositon

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [17_EigenAnalysis.ipynb](17_EigenAnalysis.ipynb) | Covers eigenvalues and eigenvectors, and their significance in matrix analysis.|
# | [18_EigenComputations.ipynb](18_EigenComputations.ipynb) | Demonstrates how to compute eigenvalues and eigenvectors for matrices.|
# | [19_Diagonalization.ipynb](19_Diagonalization.ipynb) | Introduces diagonalization and its use in simplifying matrix computations.|
# | [DifferenceEquations.ipynb](DifferenceEquations.ipynb) | Uses linear algebra to solve difference equations, a key topic in applied mathematics.|
# | [MarkovChains.ipynb](MarkovChains.ipynb) | Discusses Markov chains and their matrix representations in linear algebra.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [ComplexEigenProblems.ipynb](ComplexEigenProblems.ipynb) | Discusses eigenvalue problems involving complex matrices.|
# | [CirculantMatrices.ipynb](CirculantMatrices.ipynb) | Explores circulant matrices and their applications in linear systems.|
# | [GreshgorinCircles.ipynb](GreshgorinCircles.ipynb) | Discusses Gershgorin circles and their application to eigenvalue estimation.|
# | [HamiltonCayley.ipynb](HamiltonCayley.ipynb) | Explains the Hamilton-Cayley theorem and its applications to matrix analysis.|
# | [RayleighQuotients.ipynb](RayleighQuotients.ipynb) | Discusses Rayleigh quotients in the context of eigenvalue approximations.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [24_SpectralTheorem.ipynb](24_SpectralTheorem.ipynb) | Explains the spectral theorem and its importance in linear algebra.|
# | [25_PositiveDefiniteMatrices.ipynb](25_PositiveDefiniteMatrices.ipynb) | Covers the properties and applications of positive definite matrices.|
# | [25a_QuadricSurfaceDisplay.ipynb](25a_QuadricSurfaceDisplay.ipynb) | Visualizes quadric surfaces in 3D using linear algebra techniques.|
# | [PositiveDefiniteTests.ipynb](PositiveDefiniteTests.ipynb) | Tests for positive definiteness in matrices.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [FunctionsOfAMatrix.ipynb](FunctionsOfAMatrix.ipynb) | Explores functions of matrices, such as matrix exponentials and matrix logarithms.|
# | [FunctionsOfAMatrixExamples.ipynb](FunctionsOfAMatrixExamples.ipynb) | Provides examples of applying functions to matrices in various problems.|
# | [JordanForm.ipynb](JordanForm.ipynb) | Discusses the Jordan canonical form of matrices and its computation.|
# | [FunctionsOfADegenerateMatrix.ipynb](FunctionsOfADegenerateMatrix.ipynb) | Explores functions of degenerate matrices, such as matrix exponentials<br> and matrix logarithms when the matrix is degenerate.|
# </div>

# %% [markdown]
# # 8. Singular Value Decomposition

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [26_GramMatrix.ipynb](26_GramMatrix.ipynb) | Introduces the Gram matrix and its uses in orthogonality and projection problems.|
# | [27_SVD.ipynb](27_SVD.ipynb) | Explains Singular Value Decomposition (SVD) and its applications in data analysis.|
# | [28_PseudoInverse.ipynb](28_PseudoInverse.ipynb) | Defines the pseudoinverse of a matrix and its use in solving linear systems.|
# | [29_SVDapplications.ipynb](29_SVDapplications.ipynb) | Applies SVD to a variety of problems,<br>including image compression and data reduction.|
# | [30_VectorAndMatrixNorms.ipynb](30_VectorAndMatrixNorms.ipynb) | Introduces vector and matrix norms and their properties.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [PCA_and_SVD.ipynb](PCA_and_SVD.ipynb) | Uses Principal Component Analysis (PCA) and <br>Singular Value Decomposition (SVD) in data analysis.|
# | [SVD_RemoveForeground.ipynb](SVD_RemoveForeground.ipynb) | Uses SVD to remove foreground noise in image processing.|
# | [Eigenfaces.ipynb](Eigenfaces.ipynb) | Applies eigenvectors and eigenvalues to facial recognition technology (eigenfaces).|
# </div>

# %% [markdown]
# # 9. Randomized Algorithms, Iterative Methods

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [ConditionNumber.ipynb](ConditionNumber.ipynb) | Defines the condition number of a matrix and its significance in numerical analysis.|
# | [rSVDintroduction_python.ipynb](rSVDintroduction_python.ipynb) | Provides a Python implementation of randomized SVD.|
# | [rSVDintroduction_julia.ipynb](rSVDintroduction_julia.ipynb) | Introduces randomized SVD implementation in Julia.|
# | [rSVD.ipynb](rSVD.ipynb) | Introduces randomized SVD for faster computations on large matrices.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [IterativeMethods_julia.ipynb](IterativeMethods_julia.ipynb) | Implements iterative methods for solving linear systems using Julia programming.|
# | [IterativeMethods_python.ipynb](IterativeMethods_python.ipynb) | Demonstrates iterative methods for solving linear systems in Python.|
# | [KrylovMethods.ipynb](KrylovMethods.ipynb) | Explores Krylov subspace methods for solving large linear systems.|
# | [Arnoldi Algorithm for Eigenvalues](Arnoldi_Ritz_eigenvalues.ipynb) | Explains and implements the Arnoldi Algorithm |
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [MatrixDerivatives.ipynb](MatrixDerivatives.ipynb) | Explores the derivatives of matrix functions.|
# | [GradientDescent.ipynb](GradientDescent.ipynb) | Introduces gradient descent, a method for optimizing functions using linear algebra.|
# | [GradientDescentExample.ipynb](GradientDescentExample.ipynb) | Provides an example of gradient descent applied to a simple optimization problem.|
# | [GMRES.ipynb](GMRES.ipynb) | Discusses the GMRES (Generalized Minimal Residual) method for solving linear systems.|
# </div>

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# |      |      |
# | ---- | ---- |
# | [BackPropagation.ipynb](BackPropagation.ipynb) | Explores backpropagation in neural networks, using linear algebra for optimization.
# </div>

# %% [markdown]
# # Appendices

# %% [markdown]
# <div style="display: inline-block; padding-left: 1cm;">
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [A1_AnalyticGeometry.ipynb](A1_AnalyticGeometry.ipynb) | Discusses the relationship between linear algebra and analytic geometry.|
# | [A2_Matrix_Layout_Displays.ipynb](A2_Matrix_Layout_Displays.ipynb) | Visualizes matrix layouts and their geometric interpretation.|
#
# | <span style="margin-left:7cm;"></span> | <span style="margin-left:13cm;"></span>  |
# | ---- | ---- |
# | [A3_SymbolicVariables.ipynb](A3_SymbolicVariables.ipynb) | Uses symbolic variables in matrix computations for exact solutions.|
# | [A4_GE_layout_display.ipynb (Deprecated)](A4_GE_layout_display.ipynb) | Deprecated |
# | [A5_DrawingVectorsAndPlanes.ipynb](A5_DrawingVectorsAndPlanes.ipynb) | Provides visual examples of vectors and planes in 3D space.|
# | [A6_GenerateProblems.ipynb](A6_GenerateProblems.ipynb) | Generates problems for practicing linear algebra concepts.|
# </div>
