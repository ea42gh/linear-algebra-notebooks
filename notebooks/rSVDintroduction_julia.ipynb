# %%
#using Pkg; Pkg.add("ImageView")
using LinearAlgebra, RowEchelon, LaTeXStrings, Plots, SymPy
using Random, Distributions, Images, TestImages, Colors, ImageView

# %% [markdown]
# <div style="float:center;width:100%;text-align: center;"><strong style="height:60px;color:darkred;font-size:40px;">Randomized Linear Algebra</strong></div>

# %% [markdown]
# # 1. Images are Matrices

# %% [markdown]
# ## 1.1 Display a Matrix

# %%
A = rand(4,3)
display(A)
Gray.(A)
# Out:
# 4×3 Matrix{Float64}:
#  0.757201  0.90035   0.870939
#  0.719201  0.48527   0.806192
#  0.766867  0.756833  0.41347
#  0.817688  0.332572  0.652178
# 4×3 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.757201)  Gray{Float64}(0.90035)   Gray{Float64}(0.870939)
#  Gray{Float64}(0.719201)  Gray{Float64}(0.48527)   Gray{Float64}(0.806192)
#  Gray{Float64}(0.766867)  Gray{Float64}(0.756833)  Gray{Float64}(0.41347)
#  Gray{Float64}(0.817688)  Gray{Float64}(0.332572)  Gray{Float64}(0.652178)

# %% [markdown]
# ## 1.2 A Color Image

# %%
img = testimage("lighthouse")
println("Image type: ", typeof(img))
img
# Out:
# Image type: Matrix{RGB{N0f8}}
# 512×768 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.361,0.486,0.6)    …  RGB{N0f8}(0.349,0.49,0.529)
#  RGB{N0f8}(0.361,0.486,0.6)       RGB{N0f8}(0.369,0.498,0.58)
#  RGB{N0f8}(0.376,0.514,0.624)     RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.365,0.498,0.62)      RGB{N0f8}(0.345,0.478,0.588)
#  RGB{N0f8}(0.365,0.498,0.627)     RGB{N0f8}(0.349,0.486,0.596)
#  RGB{N0f8}(0.369,0.502,0.635)  …  RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.38,0.518,0.635)      RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.369,0.502,0.635)     RGB{N0f8}(0.376,0.502,0.616)
#  RGB{N0f8}(0.357,0.502,0.627)     RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.349,0.49,0.62)       RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.373,0.518,0.643)  …  RGB{N0f8}(0.353,0.494,0.592)
#  RGB{N0f8}(0.388,0.533,0.659)     RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.38,0.525,0.643)      RGB{N0f8}(0.376,0.514,0.624)
#  ⋮                             ⋱
#  RGB{N0f8}(0.204,0.169,0.137)  …  RGB{N0f8}(0.157,0.188,0.204)
#  RGB{N0f8}(0.169,0.133,0.118)     RGB{N0f8}(0.169,0.196,0.224)
#  RGB{N0f8}(0.149,0.122,0.11)      RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.153,0.125,0.114)     RGB{N0f8}(0.176,0.216,0.239)
#  RGB{N0f8}(0.188,0.165,0.141)     RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.31,0.298,0.263)   …  RGB{N0f8}(0.255,0.302,0.333)
#  RGB{N0f8}(0.486,0.498,0.443)     RGB{N0f8}(0.231,0.29,0.318)
#  RGB{N0f8}(0.663,0.682,0.627)     RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.702,0.745,0.678)     RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.459,0.486,0.447)     RGB{N0f8}(0.184,0.22,0.247)
#  RGB{N0f8}(0.443,0.467,0.439)  …  RGB{N0f8}(0.18,0.208,0.22)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)

# %% [markdown]
# ##### **RGB Channels**

# %%
channels = channelview(img)
println("channels type: ", typeof(channels[1,:,:]))
channels
# Out:
# channels type: Matrix{N0f8}
# 3×512×768 reinterpret(reshape, N0f8, ::Array{RGB{N0f8},2}) with eltype N0f8:
# [:, :, 1] =
#  0.361  0.361  0.376  0.365  0.365  0.369  …  0.663  0.702  0.459  0.443  0.0
#  0.486  0.486  0.514  0.498  0.498  0.502     0.682  0.745  0.486  0.467  0.0
#  0.6    0.6    0.624  0.62   0.627  0.635     0.627  0.678  0.447  0.439  0.0
#
# [:, :, 2] =
#  0.349  0.361  0.353  0.369  0.376  0.376  …  0.745  0.678  0.427  0.443  0.0
#  0.475  0.498  0.49   0.506  0.51   0.51      0.776  0.722  0.467  0.467  0.0
#  0.588  0.608  0.608  0.624  0.639  0.631     0.725  0.667  0.424  0.439  0.0
#
# [:, :, 3] =
#  0.345  0.361  0.361  0.365  0.361  0.365  …  0.843  0.616  0.514  0.486  0.0
#  0.478  0.494  0.494  0.498  0.494  0.498     0.871  0.655  0.553  0.525  0.0
#  0.588  0.616  0.616  0.62   0.616  0.62      0.82   0.612  0.518  0.49   0.0
#
# ;;; …
#
# [:, :, 766] =
#  0.329  0.357  0.357  0.349  0.361  0.357  …  0.208  0.259  0.192  0.173  0.0
#  0.463  0.486  0.482  0.475  0.486  0.482     0.255  0.31   0.231  0.204  0.0
#  0.518  0.569  0.596  0.588  0.6    0.596     0.286  0.341  0.255  0.22   0.0
#
# [:, :, 767] =
#  0.345  0.349  0.349  0.353  0.361  0.365  …  0.239  0.259  0.173  0.165  0.0
#  0.482  0.482  0.486  0.49   0.498  0.502     0.286  0.306  0.212  0.192  0.0
#  0.525  0.565  0.596  0.6    0.608  0.612     0.325  0.349  0.235  0.2    0.0
#
# [:, :, 768] =
#  0.349  0.369  0.361  0.345  0.349  0.365  …  0.267  0.267  0.184  0.18   0.0
#  0.49   0.498  0.498  0.478  0.486  0.502     0.31   0.31   0.22   0.208  0.0
#  0.529  0.58   0.608  0.588  0.596  0.612     0.353  0.353  0.247  0.22   0.0

# %%
mosaicview( Gray.(channels[1,:,:]), Gray.(channels[2,:,:]), Gray.(channels[3,:,:]); nrow=1)
# Out:
# 512×2304 MosaicView{Gray{N0f8}, 4, Base.ReshapedArray{Gray{N0f8}, 4, PaddedView{Gray{N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{N0f8}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{N0f8}}}}, OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{N0f8}}}}, OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.349)  …  Gray{N0f8}(0.529)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.361)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.376)  Gray{N0f8}(0.353)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.369)     Gray{N0f8}(0.588)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.376)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.376)  …  Gray{N0f8}(0.612)
#  Gray{N0f8}(0.38)   Gray{N0f8}(0.365)     Gray{N0f8}(0.612)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.365)     Gray{N0f8}(0.616)
#  Gray{N0f8}(0.357)  Gray{N0f8}(0.376)     Gray{N0f8}(0.604)
#  Gray{N0f8}(0.349)  Gray{N0f8}(0.376)     Gray{N0f8}(0.604)
#  Gray{N0f8}(0.373)  Gray{N0f8}(0.376)  …  Gray{N0f8}(0.592)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.369)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.38)   Gray{N0f8}(0.388)     Gray{N0f8}(0.624)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.204)  Gray{N0f8}(0.18)   …  Gray{N0f8}(0.204)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.157)     Gray{N0f8}(0.224)
#  Gray{N0f8}(0.149)  Gray{N0f8}(0.153)     Gray{N0f8}(0.294)
#  Gray{N0f8}(0.153)  Gray{N0f8}(0.165)     Gray{N0f8}(0.239)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.255)     Gray{N0f8}(0.294)
#  Gray{N0f8}(0.31)   Gray{N0f8}(0.49)   …  Gray{N0f8}(0.333)
#  Gray{N0f8}(0.486)  Gray{N0f8}(0.537)     Gray{N0f8}(0.318)
#  Gray{N0f8}(0.663)  Gray{N0f8}(0.745)     Gray{N0f8}(0.353)
#  Gray{N0f8}(0.702)  Gray{N0f8}(0.678)     Gray{N0f8}(0.353)
#  Gray{N0f8}(0.459)  Gray{N0f8}(0.427)     Gray{N0f8}(0.247)
#  Gray{N0f8}(0.443)  Gray{N0f8}(0.443)  …  Gray{N0f8}(0.22)
#  Gray{N0f8}(0.0)    Gray{N0f8}(0.0)       Gray{N0f8}(0.0)

# %% [markdown]
# ##### **Grayscale Image**

# %%
gray = Gray.(img)
display(Float64.(gray[1:5,1:3]))
gray
# Out:
# 5×3 Matrix{Float64}:
#  0.462745  0.45098   0.45098
#  0.462745  0.470588  0.466667
#  0.486275  0.462745  0.466667
#  0.470588  0.478431  0.470588
#  0.47451   0.486275  0.466667
# 512×768 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.451)  …  Gray{N0f8}(0.451)
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.471)     Gray{N0f8}(0.471)
#  Gray{N0f8}(0.486)  Gray{N0f8}(0.463)     Gray{N0f8}(0.471)
#  Gray{N0f8}(0.471)  Gray{N0f8}(0.478)     Gray{N0f8}(0.451)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.486)     Gray{N0f8}(0.459)
#  Gray{N0f8}(0.478)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.475)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.471)     Gray{N0f8}(0.475)
#  Gray{N0f8}(0.478)  Gray{N0f8}(0.471)     Gray{N0f8}(0.478)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)     Gray{N0f8}(0.475)
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.482)     Gray{N0f8}(0.475)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.482)  …  Gray{N0f8}(0.463)
#  Gray{N0f8}(0.506)  Gray{N0f8}(0.478)     Gray{N0f8}(0.471)
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.498)     Gray{N0f8}(0.486)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.176)  Gray{N0f8}(0.153)  …  Gray{N0f8}(0.18)
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.137)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.129)  Gray{N0f8}(0.129)     Gray{N0f8}(0.263)
#  Gray{N0f8}(0.133)  Gray{N0f8}(0.145)     Gray{N0f8}(0.208)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.235)     Gray{N0f8}(0.263)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.29)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.537)     Gray{N0f8}(0.275)
#  Gray{N0f8}(0.671)  Gray{N0f8}(0.761)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.725)  Gray{N0f8}(0.702)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.451)     Gray{N0f8}(0.212)
#  Gray{N0f8}(0.455)  Gray{N0f8}(0.455)  …  Gray{N0f8}(0.2)
#  Gray{N0f8}(0.0)    Gray{N0f8}(0.0)       Gray{N0f8}(0.0)

# %% [markdown]
# ##### **Image Size and Singular Values**

# %%
# define matrix A to be the grayscale matrix
A = Float64.(gray);
print("shape of A: ", size(A), ",   type of A: ", typeof(A))
# Out:
# shape of A: (512, 768),   type of A: Matrix{Float64}

# %%
svdfactors = svd(Float64.(gray))
plot(  svdfactors.S, yscale=:log10, label="Singular Values (Gray)"  )

# %% [markdown]
# # 2. Approximate the Column Space $\mathscr{C}(A)$

# %% [markdown]
# ## 2.1 Random Vectors Tend to be Orthogonal

# %%
function dot_products_of_random_unit_vectors( vec_sz, num_vecs )
    Ω = randn(Float64, (vec_sz, num_vecs)) 
    for i in 1:num_vecs
        Ω[:,i] = Ω[:,i] / norm(Ω[:,i])   # Make cols of Ω have unit length
    end
    Ω'Ω
end
println( "Look at 50 vectors with increasing sizes: [10, 100, 1000]\n") 
mosaicview( [ Gray.((x->1-x).(abs.(dot_products_of_random_unit_vectors( vec_sz, 50)))) for vec_sz in [10, 100, 1000]]..., nrow=1, npad=2 )
# Out:
# Look at 50 vectors with increasing sizes: [10, 100, 1000]
# 50×154 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)       …  Gray{Float64}(0.947288)
#  Gray{Float64}(0.845109)     Gray{Float64}(0.962161)
#  Gray{Float64}(0.916331)     Gray{Float64}(0.98348)
#  Gray{Float64}(0.459467)     Gray{Float64}(0.945017)
#  Gray{Float64}(0.844431)     Gray{Float64}(0.9242)
#  Gray{Float64}(0.765235)  …  Gray{Float64}(0.997574)
#  Gray{Float64}(0.885799)     Gray{Float64}(0.949473)
#  Gray{Float64}(0.66255)      Gray{Float64}(0.994295)
#  Gray{Float64}(0.573412)     Gray{Float64}(0.95158)
#  Gray{Float64}(0.503132)     Gray{Float64}(0.968837)
#  Gray{Float64}(0.877368)  …  Gray{Float64}(0.987033)
#  Gray{Float64}(0.965711)     Gray{Float64}(0.9358)
#  Gray{Float64}(0.910185)     Gray{Float64}(0.952664)
#  ⋮                        ⋱
#  Gray{Float64}(0.82737)      Gray{Float64}(0.983935)
#  Gray{Float64}(0.63549)      Gray{Float64}(0.992157)
#  Gray{Float64}(0.791055)  …  Gray{Float64}(0.987159)
#  Gray{Float64}(0.973599)     Gray{Float64}(0.982617)
#  Gray{Float64}(0.98598)      Gray{Float64}(0.965955)
#  Gray{Float64}(0.628435)     Gray{Float64}(0.947196)
#  Gray{Float64}(0.709831)     Gray{Float64}(0.992168)
#  Gray{Float64}(0.262929)  …  Gray{Float64}(0.962853)
#  Gray{Float64}(0.989002)     Gray{Float64}(0.994535)
#  Gray{Float64}(0.949281)     Gray{Float64}(0.968544)
#  Gray{Float64}(0.704389)     Gray{Float64}(0.979133)
#  Gray{Float64}(0.719225)     Gray{Float64}(0.0)

# %% [markdown]
# ## 2.2 Random Samples of the Column Space

# %%
# Sample the column Space
#   take k linear combinations of random columns of A
#   perform QR and return Q (a basis for a subspace of Col(A) )
function approx_ColA( A, k )
    Aapprox = A * randn(Float64, (size(A,2), k))
    Matrix(qr(Aapprox).Q)
end;

# %% [markdown]
# Our `approx_ColA(A,n)` samples the column Space $\mathscr{C}(A)$ in roughly orthogonal directions<br>
# $\qquad$ use QR to orthogonalize the resulting samples: matrix $Q$
#
# Sizes:
# * $A$ is $M\times N$
# * $Q$ is $M \times K$, where we want $K << N$  (long and skinny)

# %% [markdown]
# **Remark:** $A$ does not have to be in memory at the same time!

# %% [markdown]
# What happens when we project $A$ onto $\mathscr{C}(Q)$, i.e., when we compute $Q Q^t A$

# %%
Aapprox_list = []
choice_of_K = [10,25,100]
for k in choice_of_K
    Q = approx_ColA( A, k)
    push!(Aapprox_list, Gray.(Q*Q'A) )   # project A onto Q
end
println( "Size A = ", size(A) )
println( "Sizes of Q = ", choice_of_K )
println()
mosaicview( Aapprox_list...; nrow=1)
# Out:
# Size A = (512, 768)
# Sizes of Q = [10, 25, 100]
# 512×2304 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.47122)   Gray{Float64}(0.470461)  …  Gray{Float64}(0.483548)
#  Gray{Float64}(0.466804)  Gray{Float64}(0.465925)     Gray{Float64}(0.468809)
#  Gray{Float64}(0.473008)  Gray{Float64}(0.473358)     Gray{Float64}(0.478104)
#  Gray{Float64}(0.467706)  Gray{Float64}(0.467269)     Gray{Float64}(0.463794)
#  Gray{Float64}(0.469442)  Gray{Float64}(0.46981)      Gray{Float64}(0.469779)
#  Gray{Float64}(0.472966)  Gray{Float64}(0.473497)  …  Gray{Float64}(0.485515)
#  Gray{Float64}(0.475969)  Gray{Float64}(0.475961)     Gray{Float64}(0.472472)
#  Gray{Float64}(0.476753)  Gray{Float64}(0.475958)     Gray{Float64}(0.480266)
#  Gray{Float64}(0.480609)  Gray{Float64}(0.480151)     Gray{Float64}(0.481706)
#  Gray{Float64}(0.481387)  Gray{Float64}(0.481375)     Gray{Float64}(0.479504)
#  Gray{Float64}(0.481215)  Gray{Float64}(0.480829)  …  Gray{Float64}(0.473578)
#  Gray{Float64}(0.479834)  Gray{Float64}(0.479995)     Gray{Float64}(0.490692)
#  Gray{Float64}(0.478548)  Gray{Float64}(0.478963)     Gray{Float64}(0.462727)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.307932)  Gray{Float64}(0.322079)  …  Gray{Float64}(0.208523)
#  Gray{Float64}(0.26948)   Gray{Float64}(0.286051)     Gray{Float64}(0.168509)
#  Gray{Float64}(0.242368)  Gray{Float64}(0.257687)     Gray{Float64}(0.222153)
#  Gray{Float64}(0.310633)  Gray{Float64}(0.314835)     Gray{Float64}(0.220558)
#  Gray{Float64}(0.315564)  Gray{Float64}(0.326656)     Gray{Float64}(0.212416)
#  Gray{Float64}(0.327688)  Gray{Float64}(0.348324)  …  Gray{Float64}(0.295073)
#  Gray{Float64}(0.373711)  Gray{Float64}(0.378929)     Gray{Float64}(0.276165)
#  Gray{Float64}(0.410092)  Gray{Float64}(0.41212)      Gray{Float64}(0.304266)
#  Gray{Float64}(0.445501)  Gray{Float64}(0.450832)     Gray{Float64}(0.297859)
#  Gray{Float64}(0.515258)  Gray{Float64}(0.52485)      Gray{Float64}(0.250541)
#  Gray{Float64}(0.440197)  Gray{Float64}(0.443749)  …  Gray{Float64}(0.167105)
#  Gray{Float64}(0.0)       Gray{Float64}(0.0)          Gray{Float64}(0.0)

# %%
mosaicview( [(x->1-x).(img-gray) for img in Aapprox_list]...; nrow=1)
# Out:
# 512×2304 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.991525)  Gray{Float64}(0.980519)  …  Gray{Float64}(0.967432)
#  Gray{Float64}(0.995941)  Gray{Float64}(1.00466)      Gray{Float64}(1.00178)
#  Gray{Float64}(1.01327)   Gray{Float64}(0.989387)     Gray{Float64}(0.992484)
#  Gray{Float64}(1.00288)   Gray{Float64}(1.01116)      Gray{Float64}(0.987187)
#  Gray{Float64}(1.00507)   Gray{Float64}(1.01646)      Gray{Float64}(0.989044)
#  Gray{Float64}(1.00547)   Gray{Float64}(1.00886)   …  Gray{Float64}(0.988995)
#  Gray{Float64}(1.01423)   Gray{Float64}(0.994627)     Gray{Float64}(1.00204)
#  Gray{Float64}(1.00168)   Gray{Float64}(0.99463)      Gray{Float64}(0.998165)
#  Gray{Float64}(0.993901)  Gray{Float64}(1.0022)       Gray{Float64}(0.992803)
#  Gray{Float64}(0.981358)  Gray{Float64}(1.00098)      Gray{Float64}(0.995006)
#  Gray{Float64}(1.00898)   Gray{Float64}(1.00152)   …  Gray{Float64}(0.989167)
#  Gray{Float64}(1.02605)   Gray{Float64}(0.998437)     Gray{Float64}(0.979896)
#  Gray{Float64}(1.01557)   Gray{Float64}(1.01908)      Gray{Float64}(1.02355)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.868539)  Gray{Float64}(0.830862)  …  Gray{Float64}(0.97187)
#  Gray{Float64}(0.871696)  Gray{Float64}(0.851204)     Gray{Float64}(1.02365)
#  Gray{Float64}(0.887044)  Gray{Float64}(0.871724)     Gray{Float64}(1.04059)
#  Gray{Float64}(0.8227)    Gray{Float64}(0.830263)     Gray{Float64}(0.987285)
#  Gray{Float64}(0.853063)  Gray{Float64}(0.908638)     Gray{Float64}(1.05033)
#  Gray{Float64}(0.970351)  Gray{Float64}(1.13403)   …  Gray{Float64}(0.995123)
#  Gray{Float64}(1.11648)   Gray{Float64}(1.15833)      Gray{Float64}(0.998345)
#  Gray{Float64}(1.2605)    Gray{Float64}(1.34866)      Gray{Float64}(0.997694)
#  Gray{Float64}(1.27999)   Gray{Float64}(1.25113)      Gray{Float64}(1.0041)
#  Gray{Float64}(0.959252)  Gray{Float64}(0.926131)     Gray{Float64}(0.961224)
#  Gray{Float64}(1.01471)   Gray{Float64}(1.01115)   …  Gray{Float64}(1.0329)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(1.0)

# %% [markdown]
# # 3. Matrix Factorizations

# %% [markdown]
# ____
# **Idea:** Approximate $A \approx Q Q^{t} A$, and apply matrix factorization algorithms to the much smaller $Q^t A$ rather than $A$.
# * $A\qquad$ is $M\times N$
# * $Q\qquad$ is $M\times K$, where $K << min(M,N)$
# * $Q^t A\quad$ is $K \times N$

# %% [markdown]
# Consider the SVD decomposition $A = U \Sigma V^t$.<br>
# $\quad$ Then $Q^t A = Q^t U \Sigma V^t = \tilde{U} \Sigma V^t,$<br>
# $\quad$ so that the SVD of $Q^t A$ and the SVD of $A$ are related:<br>
# * they have the same singular values $\Sigma$ and the same singular vectors in $V$.
# * the singular vectors $\tilde{U}$ of $Q^t A$ are related to the singular vectors $U$ of $A$ by
# $U = Q^t \tilde{U}$

# %% [markdown]
# # 4. Randomized SVD

# %% [markdown]
# Suppose we can find an orthogonal matrix $Q$ such that $A \approx Q Q^t A$,<br>
# we can use this approximation to compute an approximate matrix decomposition of $A$.
#
# Matrix Sizes:
# * Let $A$ have size $M \times N$
# * Let $Q$ have size $M \times K$, where $K < N$.
# * Then $Q^t A$ has size $K \times N$. potentially much smaller that the original matrix.
#
# * The $\tilde{U}$ matrix of our SVD has size $K \times K$. (The original matrix $U$ is $N \times N$
#
# How to choose $K$?  Usually, $K = rank(A) + l,$ where $l \approx 5$.

# %%
function randomized_svd(A; k=5, may_transpose = false)
    if may_transpose
        transpose = size(A,1) < size(A,2)
        if transpose A = A' end
    end

    Q   = approx_ColA( A, k )
    QtA = Q'A

    svd_QtA = svd( QtA )
    U       = Q * svd_QtA.U

    if may_transpose && transpose
        SVD( svd_QtA.V, svd_QtA.S, Matrix(U') )
    else
        SVD( U, svd_QtA.S, svd_QtA.V' )
    end
end
function svdErr( svdA, A )
    norm( svdA.U * diagm( svdA.S ) * svdA.Vt  - A )
end

K=100
println( "Matrix size:    ", size(A) )
println( ".  choice of K: ", K )
svdA  = randomized_svd(A'; k=K)
@show svdErr( svdA, A' );
# Out:
# Matrix size:    (512, 768)
# .  choice of K: 100
# svdErr(svdA, A') = 28.169564828332344

# %% [markdown]
# ## 4.1 Randomized SVD

# %% [markdown]
# ____
# **Idea:** Power $(A^t A)^p A$ changes the distribution of the singular values
#
# $  \begin{align} A = U \Sigma V^t \Rightarrow
# \left( A A^t \right)^p A &= \left( U \Sigma \Sigma^t U^t \right)^p \left( U \Sigma V^t \right) \\
# &= U_r \Sigma^{p+1}_r V^t_r
# \end{align}.$

# %%
svdA = svd(A)
plot(  svdA.S/svdA.S[1], yscale=:log10, label="p=0", ylim=(1e-20,10)  )
Z = A
for p in 1:5
    Z    = A * (A'Z)
    svdZ = svd(Z)
    plot!( svdZ.S / svdZ.S[1], yscale=:log10, label="p=$p"  )
end
title!( "Relative Singular Values (Grayscale Image)")

# %% [markdown]
# ## 4.2 Randomized SVD with Power

# %%
function approxCol_Ap( A, p, k)
    Aapprox = A * randn(Float64, (size(A,2), k))
    for n in 1:p
        Aapprox = A * ( A'Aapprox)    # Z = (A A.T)^p A v
    end
    Matrix(qr(Aapprox).Q)
end
function randomized_svd_Ap(A; p=3, k=5)
    Q   = approxCol_Ap( A, p, k )
    QtA = Q'A

    svd_QtA = svd( QtA )
    U       = Q * svd_QtA.U

    SVD( U, svd_QtA.S, svd_QtA.V' )
end

K=100
println( "Matrix size:    ", size(A) )
println( ".  choice of K: ", K )
println( ".  svdErr as a function of the power" )
err = [svdErr( randomized_svd_Ap(A'; p, k=K), A' ) for p in 0:10]
plot(err)
# Out:
# Matrix size:    (512, 768)
# .  choice of K: 100
# .  svdErr as a function of the power

# %% [markdown]
# https://www.youtube.com/watch?v=mQlzdDTRJpU
# https://www.youtube.com/watch?v=dyeSHiwntxY
