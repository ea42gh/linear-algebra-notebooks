# %%
using LinearAlgebra
using Plots, Images, ImageShow, TestImages

# %% [markdown]
# <div style="float:center;width:100%;text-align: center;"><strong style="height:60px;color:darkred;font-size:40px;">Randomized Linear Algebra</strong></div>

# %% [markdown]
# # 1. Images are Matrices

# %% [markdown]
# ## 1.1 Display a Matrix

# %%
A = rand(4,3)
display(A)
Gray.(A)
# Out:
# 4×3 Matrix{Float64}:
#  0.918836  0.746736  0.429076
#  0.198261  0.336014  0.268005
#  0.261415  0.99899   0.6689
#  0.362339  0.979028  0.97552
# 4×3 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.918836)  Gray{Float64}(0.746736)  Gray{Float64}(0.429076)
#  Gray{Float64}(0.198261)  Gray{Float64}(0.336014)  Gray{Float64}(0.268005)
#  Gray{Float64}(0.261415)  Gray{Float64}(0.99899)   Gray{Float64}(0.6689)
#  Gray{Float64}(0.362339)  Gray{Float64}(0.979028)  Gray{Float64}(0.97552)

# %% [markdown]
# ## 1.2 A Color Image

# %%
img = testimage("lighthouse")
println("Image type: ", typeof(img))
img
# Out:
# Image type: Matrix
# {RGB
# {N0f8}}
# 512×768 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.361,0.486,0.6)    RGB{N0f8}(0.349,0.475,0.588)  RGB{N0f8}(0.345,0.478,0.588)  …  RGB{N0f8}(0.345,0.482,0.525)  RGB{N0f8}(0.349,0.49,0.529)
#  RGB{N0f8}(0.361,0.486,0.6)    RGB{N0f8}(0.361,0.498,0.608)  RGB{N0f8}(0.361,0.494,0.616)     RGB{N0f8}(0.349,0.482,0.565)  RGB{N0f8}(0.369,0.498,0.58)
#  RGB{N0f8}(0.376,0.514,0.624)  RGB{N0f8}(0.353,0.49,0.608)   RGB{N0f8}(0.361,0.494,0.616)     RGB{N0f8}(0.349,0.486,0.596)  RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.365,0.498,0.62)   RGB{N0f8}(0.369,0.506,0.624)  RGB{N0f8}(0.365,0.498,0.62)      RGB{N0f8}(0.353,0.49,0.6)     RGB{N0f8}(0.345,0.478,0.588)
#  RGB{N0f8}(0.365,0.498,0.627)  RGB{N0f8}(0.376,0.51,0.639)   RGB{N0f8}(0.361,0.494,0.616)     RGB{N0f8}(0.361,0.498,0.608)  RGB{N0f8}(0.349,0.486,0.596)
#  RGB{N0f8}(0.369,0.502,0.635)  RGB{N0f8}(0.376,0.51,0.631)   RGB{N0f8}(0.365,0.498,0.62)   …  RGB{N0f8}(0.365,0.502,0.612)  RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.38,0.518,0.635)   RGB{N0f8}(0.365,0.498,0.62)   RGB{N0f8}(0.369,0.506,0.624)     RGB{N0f8}(0.361,0.498,0.608)  RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.369,0.502,0.635)  RGB{N0f8}(0.365,0.498,0.62)   RGB{N0f8}(0.353,0.49,0.608)      RGB{N0f8}(0.349,0.475,0.588)  RGB{N0f8}(0.376,0.502,0.616)
#  RGB{N0f8}(0.357,0.502,0.627)  RGB{N0f8}(0.376,0.51,0.631)   RGB{N0f8}(0.388,0.522,0.631)     RGB{N0f8}(0.369,0.494,0.596)  RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.349,0.49,0.62)    RGB{N0f8}(0.376,0.51,0.631)   RGB{N0f8}(0.38,0.518,0.627)      RGB{N0f8}(0.369,0.494,0.596)  RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.373,0.518,0.643)  RGB{N0f8}(0.376,0.51,0.631)   RGB{N0f8}(0.376,0.514,0.624)  …  RGB{N0f8}(0.361,0.498,0.596)  RGB{N0f8}(0.353,0.494,0.592)
#  RGB{N0f8}(0.388,0.533,0.659)  RGB{N0f8}(0.369,0.506,0.624)  RGB{N0f8}(0.369,0.506,0.624)     RGB{N0f8}(0.349,0.486,0.596)  RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.38,0.525,0.643)   RGB{N0f8}(0.388,0.522,0.651)  RGB{N0f8}(0.376,0.51,0.639)      RGB{N0f8}(0.353,0.49,0.6)     RGB{N0f8}(0.376,0.514,0.624)
#  RGB{N0f8}(0.365,0.498,0.62)   RGB{N0f8}(0.38,0.514,0.643)   RGB{N0f8}(0.376,0.51,0.639)      RGB{N0f8}(0.369,0.506,0.624)  RGB{N0f8}(0.365,0.498,0.62)
#  RGB{N0f8}(0.365,0.498,0.62)   RGB{N0f8}(0.392,0.525,0.655)  RGB{N0f8}(0.376,0.51,0.639)      RGB{N0f8}(0.376,0.51,0.631)   RGB{N0f8}(0.365,0.498,0.62)
#  RGB{N0f8}(0.369,0.502,0.635)  RGB{N0f8}(0.38,0.514,0.643)   RGB{N0f8}(0.376,0.51,0.639)   …  RGB{N0f8}(0.361,0.486,0.6)    RGB{N0f8}(0.369,0.49,0.608)
#  RGB{N0f8}(0.376,0.51,0.639)   RGB{N0f8}(0.388,0.522,0.651)  RGB{N0f8}(0.373,0.518,0.643)     RGB{N0f8}(0.369,0.482,0.592)  RGB{N0f8}(0.373,0.49,0.596)
#  ⋮                                                                                         ⋱
#  RGB{N0f8}(0.243,0.216,0.204)  RGB{N0f8}(0.29,0.263,0.251)   RGB{N0f8}(0.282,0.251,0.243)  …  RGB{N0f8}(0.224,0.259,0.306)  RGB{N0f8}(0.224,0.259,0.306)
#  RGB{N0f8}(0.149,0.122,0.11)   RGB{N0f8}(0.2,0.173,0.161)    RGB{N0f8}(0.263,0.239,0.216)     RGB{N0f8}(0.286,0.333,0.376)  RGB{N0f8}(0.251,0.294,0.337)
#  RGB{N0f8}(0.165,0.137,0.125)  RGB{N0f8}(0.165,0.137,0.125)  RGB{N0f8}(0.208,0.169,0.153)     RGB{N0f8}(0.267,0.31,0.353)   RGB{N0f8}(0.259,0.306,0.349)
#  RGB{N0f8}(0.173,0.145,0.133)  RGB{N0f8}(0.192,0.153,0.145)  RGB{N0f8}(0.204,0.165,0.149)     RGB{N0f8}(0.278,0.325,0.357)  RGB{N0f8}(0.278,0.325,0.357)
#  RGB{N0f8}(0.18,0.145,0.125)   RGB{N0f8}(0.212,0.176,0.157)  RGB{N0f8}(0.212,0.173,0.169)     RGB{N0f8}(0.239,0.278,0.306)  RGB{N0f8}(0.247,0.286,0.31)
#  RGB{N0f8}(0.204,0.169,0.137)  RGB{N0f8}(0.18,0.145,0.125)   RGB{N0f8}(0.184,0.157,0.145)  …  RGB{N0f8}(0.157,0.188,0.204)  RGB{N0f8}(0.157,0.188,0.204)
#  RGB{N0f8}(0.169,0.133,0.118)  RGB{N0f8}(0.157,0.129,0.118)  RGB{N0f8}(0.149,0.118,0.118)     RGB{N0f8}(0.173,0.2,0.231)    RGB{N0f8}(0.169,0.196,0.224)
#  RGB{N0f8}(0.149,0.122,0.11)   RGB{N0f8}(0.153,0.122,0.122)  RGB{N0f8}(0.176,0.161,0.153)     RGB{N0f8}(0.251,0.29,0.314)   RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.153,0.125,0.114)  RGB{N0f8}(0.165,0.137,0.125)  RGB{N0f8}(0.169,0.149,0.133)     RGB{N0f8}(0.188,0.227,0.251)  RGB{N0f8}(0.176,0.216,0.239)
#  RGB{N0f8}(0.188,0.165,0.141)  RGB{N0f8}(0.255,0.227,0.208)  RGB{N0f8}(0.365,0.349,0.314)     RGB{N0f8}(0.2,0.235,0.263)    RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.31,0.298,0.263)   RGB{N0f8}(0.49,0.486,0.447)   RGB{N0f8}(0.584,0.584,0.545)  …  RGB{N0f8}(0.255,0.302,0.333)  RGB{N0f8}(0.255,0.302,0.333)
#  RGB{N0f8}(0.486,0.498,0.443)  RGB{N0f8}(0.537,0.545,0.494)  RGB{N0f8}(0.592,0.612,0.557)     RGB{N0f8}(0.247,0.306,0.333)  RGB{N0f8}(0.231,0.29,0.318)
#  RGB{N0f8}(0.663,0.682,0.627)  RGB{N0f8}(0.745,0.776,0.725)  RGB{N0f8}(0.843,0.871,0.82)      RGB{N0f8}(0.239,0.286,0.325)  RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.702,0.745,0.678)  RGB{N0f8}(0.678,0.722,0.667)  RGB{N0f8}(0.616,0.655,0.612)     RGB{N0f8}(0.259,0.306,0.349)  RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.459,0.486,0.447)  RGB{N0f8}(0.427,0.467,0.424)  RGB{N0f8}(0.514,0.553,0.518)     RGB{N0f8}(0.173,0.212,0.235)  RGB{N0f8}(0.184,0.22,0.247)
#  RGB{N0f8}(0.443,0.467,0.439)  RGB{N0f8}(0.443,0.467,0.439)  RGB{N0f8}(0.486,0.525,0.49)   …  RGB{N0f8}(0.165,0.192,0.2)    RGB{N0f8}(0.18,0.208,0.22)
#  RGB{N0f8}(0.0,0.0,0.0)        RGB{N0f8}(0.0,0.0,0.0)        RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)        RGB{N0f8}(0.0,0.0,0.0)

# %% [markdown]
# ##### **RGB Channels**

# %%
channels = channelview(img)
println("channels type: ", typeof(channels[1,:,:]))
channels
# Out:
# channels type: Matrix{N0f8}
# 3×512×768 reinterpret(reshape, N0f8, ::Array{RGB{N0f8},2}) with eltype N0f8:
# [:, :, 1] =
#  0.361  0.361  0.376  0.365  0.365  0.369  0.38   0.369  0.357  0.349  0.373  0.388  …  0.204  0.169  0.149  0.153  0.188  0.31   0.486  0.663  0.702  0.459  0.443  0.0
#  0.486  0.486  0.514  0.498  0.498  0.502  0.518  0.502  0.502  0.49   0.518  0.533     0.169  0.133  0.122  0.125  0.165  0.298  0.498  0.682  0.745  0.486  0.467  0.0
#  0.6    0.6    0.624  0.62   0.627  0.635  0.635  0.635  0.627  0.62   0.643  0.659     0.137  0.118  0.11   0.114  0.141  0.263  0.443  0.627  0.678  0.447  0.439  0.0
#
# [:, :, 2] =
#  0.349  0.361  0.353  0.369  0.376  0.376  0.365  0.365  0.376  0.376  0.376  0.369  …  0.18   0.157  0.153  0.165  0.255  0.49   0.537  0.745  0.678  0.427  0.443  0.0
#  0.475  0.498  0.49   0.506  0.51   0.51   0.498  0.498  0.51   0.51   0.51   0.506     0.145  0.129  0.122  0.137  0.227  0.486  0.545  0.776  0.722  0.467  0.467  0.0
#  0.588  0.608  0.608  0.624  0.639  0.631  0.62   0.62   0.631  0.631  0.631  0.624     0.125  0.118  0.122  0.125  0.208  0.447  0.494  0.725  0.667  0.424  0.439  0.0
#
# [:, :, 3] =
#  0.345  0.361  0.361  0.365  0.361  0.365  0.369  0.353  0.388  0.38   0.376  0.369  …  0.184  0.149  0.176  0.169  0.365  0.584  0.592  0.843  0.616  0.514  0.486  0.0
#  0.478  0.494  0.494  0.498  0.494  0.498  0.506  0.49   0.522  0.518  0.514  0.506     0.157  0.118  0.161  0.149  0.349  0.584  0.612  0.871  0.655  0.553  0.525  0.0
#  0.588  0.616  0.616  0.62   0.616  0.62   0.624  0.608  0.631  0.627  0.624  0.624     0.145  0.118  0.153  0.133  0.314  0.545  0.557  0.82   0.612  0.518  0.49   0.0
#
# ;;; …
#
# [:, :, 766] =
#  0.329  0.357  0.357  0.349  0.361  0.357  0.361  0.361  0.361  0.373  0.376  0.361  …  0.165  0.176  0.251  0.192  0.204  0.243  0.251  0.208  0.259  0.192  0.173  0.0
#  0.463  0.486  0.482  0.475  0.486  0.482  0.486  0.486  0.486  0.498  0.506  0.49      0.192  0.216  0.286  0.227  0.239  0.29   0.298  0.255  0.31   0.231  0.204  0.0
#  0.518  0.569  0.596  0.588  0.6    0.596  0.6    0.6    0.6    0.604  0.608  0.592     0.22   0.239  0.325  0.267  0.275  0.325  0.329  0.286  0.341  0.255  0.22   0.0
#
# [:, :, 767] =
#  0.345  0.349  0.349  0.353  0.361  0.365  0.361  0.349  0.369  0.369  0.361  0.349  …  0.157  0.173  0.251  0.188  0.2    0.255  0.247  0.239  0.259  0.173  0.165  0.0
#  0.482  0.482  0.486  0.49   0.498  0.502  0.498  0.475  0.494  0.494  0.498  0.486     0.188  0.2    0.29   0.227  0.235  0.302  0.306  0.286  0.306  0.212  0.192  0.0
#  0.525  0.565  0.596  0.6    0.608  0.612  0.608  0.588  0.596  0.596  0.596  0.596     0.204  0.231  0.314  0.251  0.263  0.333  0.333  0.325  0.349  0.235  0.2    0.0
#
# [:, :, 768] =
#  0.349  0.369  0.361  0.345  0.349  0.365  0.365  0.376  0.373  0.373  0.353  0.361  …  0.157  0.169  0.231  0.176  0.231  0.255  0.231  0.267  0.267  0.184  0.18   0.0
#  0.49   0.498  0.498  0.478  0.486  0.502  0.502  0.502  0.498  0.498  0.494  0.498     0.188  0.196  0.271  0.216  0.271  0.302  0.29   0.31   0.31   0.22   0.208  0.0
#  0.529  0.58   0.608  0.588  0.596  0.612  0.612  0.616  0.604  0.604  0.592  0.608     0.204  0.224  0.294  0.239  0.294  0.333  0.318  0.353  0.353  0.247  0.22   0.0

# %%
mosaicview( Gray.(channels[1,:,:]), Gray.(channels[2,:,:]), Gray.(channels[3,:,:]); nrow=1)
# Out:
# 512×2304 MosaicView{Gray{N0f8}, 4, Base.ReshapedArray{Gray{N0f8}, 4, PaddedView{Gray{N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{N0f8}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{N0f8}}}}, OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{N0f8}}}}, OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.349)  Gray{N0f8}(0.345)  Gray{N0f8}(0.376)  …  Gray{N0f8}(0.525)  Gray{N0f8}(0.518)  Gray{N0f8}(0.525)  Gray{N0f8}(0.529)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.361)  Gray{N0f8}(0.361)  Gray{N0f8}(0.361)     Gray{N0f8}(0.576)  Gray{N0f8}(0.569)  Gray{N0f8}(0.565)  Gray{N0f8}(0.58)
#  Gray{N0f8}(0.376)  Gray{N0f8}(0.353)  Gray{N0f8}(0.361)  Gray{N0f8}(0.361)     Gray{N0f8}(0.588)  Gray{N0f8}(0.596)  Gray{N0f8}(0.596)  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.369)  Gray{N0f8}(0.365)  Gray{N0f8}(0.361)     Gray{N0f8}(0.576)  Gray{N0f8}(0.588)  Gray{N0f8}(0.6)    Gray{N0f8}(0.588)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.376)  Gray{N0f8}(0.361)  Gray{N0f8}(0.365)     Gray{N0f8}(0.592)  Gray{N0f8}(0.6)    Gray{N0f8}(0.608)  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.376)  Gray{N0f8}(0.365)  Gray{N0f8}(0.365)  …  Gray{N0f8}(0.596)  Gray{N0f8}(0.596)  Gray{N0f8}(0.612)  Gray{N0f8}(0.612)
#  Gray{N0f8}(0.38)   Gray{N0f8}(0.365)  Gray{N0f8}(0.369)  Gray{N0f8}(0.365)     Gray{N0f8}(0.592)  Gray{N0f8}(0.6)    Gray{N0f8}(0.608)  Gray{N0f8}(0.612)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.365)  Gray{N0f8}(0.353)  Gray{N0f8}(0.369)     Gray{N0f8}(0.6)    Gray{N0f8}(0.6)    Gray{N0f8}(0.588)  Gray{N0f8}(0.616)
#  Gray{N0f8}(0.357)  Gray{N0f8}(0.376)  Gray{N0f8}(0.388)  Gray{N0f8}(0.369)     Gray{N0f8}(0.6)    Gray{N0f8}(0.6)    Gray{N0f8}(0.596)  Gray{N0f8}(0.604)
#  Gray{N0f8}(0.349)  Gray{N0f8}(0.376)  Gray{N0f8}(0.38)   Gray{N0f8}(0.388)     Gray{N0f8}(0.616)  Gray{N0f8}(0.604)  Gray{N0f8}(0.596)  Gray{N0f8}(0.604)
#  Gray{N0f8}(0.373)  Gray{N0f8}(0.376)  Gray{N0f8}(0.376)  Gray{N0f8}(0.38)   …  Gray{N0f8}(0.608)  Gray{N0f8}(0.608)  Gray{N0f8}(0.596)  Gray{N0f8}(0.592)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.369)  Gray{N0f8}(0.369)  Gray{N0f8}(0.38)      Gray{N0f8}(0.592)  Gray{N0f8}(0.592)  Gray{N0f8}(0.596)  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.38)   Gray{N0f8}(0.388)  Gray{N0f8}(0.376)  Gray{N0f8}(0.369)     Gray{N0f8}(0.604)  Gray{N0f8}(0.588)  Gray{N0f8}(0.6)    Gray{N0f8}(0.624)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.38)   Gray{N0f8}(0.376)  Gray{N0f8}(0.376)     Gray{N0f8}(0.612)  Gray{N0f8}(0.6)    Gray{N0f8}(0.624)  Gray{N0f8}(0.62)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.392)  Gray{N0f8}(0.376)  Gray{N0f8}(0.369)     Gray{N0f8}(0.6)    Gray{N0f8}(0.608)  Gray{N0f8}(0.631)  Gray{N0f8}(0.62)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.38)   Gray{N0f8}(0.376)  Gray{N0f8}(0.376)  …  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)    Gray{N0f8}(0.6)    Gray{N0f8}(0.608)
#  Gray{N0f8}(0.376)  Gray{N0f8}(0.388)  Gray{N0f8}(0.373)  Gray{N0f8}(0.369)     Gray{N0f8}(0.604)  Gray{N0f8}(0.592)  Gray{N0f8}(0.592)  Gray{N0f8}(0.596)
#  ⋮                                                                           ⋱  ⋮
#  Gray{N0f8}(0.243)  Gray{N0f8}(0.29)   Gray{N0f8}(0.282)  Gray{N0f8}(0.263)  …  Gray{N0f8}(0.322)  Gray{N0f8}(0.306)  Gray{N0f8}(0.306)  Gray{N0f8}(0.306)
#  Gray{N0f8}(0.149)  Gray{N0f8}(0.2)    Gray{N0f8}(0.263)  Gray{N0f8}(0.282)     Gray{N0f8}(0.361)  Gray{N0f8}(0.384)  Gray{N0f8}(0.376)  Gray{N0f8}(0.337)
#  Gray{N0f8}(0.165)  Gray{N0f8}(0.165)  Gray{N0f8}(0.208)  Gray{N0f8}(0.263)     Gray{N0f8}(0.345)  Gray{N0f8}(0.345)  Gray{N0f8}(0.353)  Gray{N0f8}(0.349)
#  Gray{N0f8}(0.173)  Gray{N0f8}(0.192)  Gray{N0f8}(0.204)  Gray{N0f8}(0.263)     Gray{N0f8}(0.357)  Gray{N0f8}(0.361)  Gray{N0f8}(0.357)  Gray{N0f8}(0.357)
#  Gray{N0f8}(0.18)   Gray{N0f8}(0.212)  Gray{N0f8}(0.212)  Gray{N0f8}(0.282)     Gray{N0f8}(0.325)  Gray{N0f8}(0.298)  Gray{N0f8}(0.306)  Gray{N0f8}(0.31)
#  Gray{N0f8}(0.204)  Gray{N0f8}(0.18)   Gray{N0f8}(0.184)  Gray{N0f8}(0.263)  …  Gray{N0f8}(0.224)  Gray{N0f8}(0.22)   Gray{N0f8}(0.204)  Gray{N0f8}(0.204)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.157)  Gray{N0f8}(0.149)  Gray{N0f8}(0.208)     Gray{N0f8}(0.271)  Gray{N0f8}(0.239)  Gray{N0f8}(0.231)  Gray{N0f8}(0.224)
#  Gray{N0f8}(0.149)  Gray{N0f8}(0.153)  Gray{N0f8}(0.176)  Gray{N0f8}(0.192)     Gray{N0f8}(0.314)  Gray{N0f8}(0.325)  Gray{N0f8}(0.314)  Gray{N0f8}(0.294)
#  Gray{N0f8}(0.153)  Gray{N0f8}(0.165)  Gray{N0f8}(0.169)  Gray{N0f8}(0.239)     Gray{N0f8}(0.31)   Gray{N0f8}(0.267)  Gray{N0f8}(0.251)  Gray{N0f8}(0.239)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.255)  Gray{N0f8}(0.365)  Gray{N0f8}(0.529)     Gray{N0f8}(0.314)  Gray{N0f8}(0.275)  Gray{N0f8}(0.263)  Gray{N0f8}(0.294)
#  Gray{N0f8}(0.31)   Gray{N0f8}(0.49)   Gray{N0f8}(0.584)  Gray{N0f8}(0.494)  …  Gray{N0f8}(0.298)  Gray{N0f8}(0.325)  Gray{N0f8}(0.333)  Gray{N0f8}(0.333)
#  Gray{N0f8}(0.486)  Gray{N0f8}(0.537)  Gray{N0f8}(0.592)  Gray{N0f8}(0.604)     Gray{N0f8}(0.314)  Gray{N0f8}(0.329)  Gray{N0f8}(0.333)  Gray{N0f8}(0.318)
#  Gray{N0f8}(0.663)  Gray{N0f8}(0.745)  Gray{N0f8}(0.843)  Gray{N0f8}(0.753)     Gray{N0f8}(0.286)  Gray{N0f8}(0.286)  Gray{N0f8}(0.325)  Gray{N0f8}(0.353)
#  Gray{N0f8}(0.702)  Gray{N0f8}(0.678)  Gray{N0f8}(0.616)  Gray{N0f8}(0.541)     Gray{N0f8}(0.341)  Gray{N0f8}(0.341)  Gray{N0f8}(0.349)  Gray{N0f8}(0.353)
#  Gray{N0f8}(0.459)  Gray{N0f8}(0.427)  Gray{N0f8}(0.514)  Gray{N0f8}(0.655)     Gray{N0f8}(0.282)  Gray{N0f8}(0.255)  Gray{N0f8}(0.235)  Gray{N0f8}(0.247)
#  Gray{N0f8}(0.443)  Gray{N0f8}(0.443)  Gray{N0f8}(0.486)  Gray{N0f8}(0.529)  …  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)   Gray{N0f8}(0.2)    Gray{N0f8}(0.22)
#  Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)       Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)

# %% [markdown]
# ##### **Grayscale Image**

# %%
gray = Gray.(img)
display(Float64.(gray[1:5,1:3]))
gray
# Out:
# 5×3 Matrix{Float64}:
#  0.462745  0.45098   0.45098
#  0.462745  0.470588  0.466667
#  0.486275  0.462745  0.466667
#  0.470588  0.478431  0.470588
#  0.47451   0.486275  0.466667
# 512×768 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.451)  Gray{N0f8}(0.451)  Gray{N0f8}(0.486)  …  Gray{N0f8}(0.439)  Gray{N0f8}(0.427)  Gray{N0f8}(0.447)  Gray{N0f8}(0.451)
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.471)  Gray{N0f8}(0.467)  Gray{N0f8}(0.471)     Gray{N0f8}(0.463)  Gray{N0f8}(0.459)  Gray{N0f8}(0.451)  Gray{N0f8}(0.471)
#  Gray{N0f8}(0.486)  Gray{N0f8}(0.463)  Gray{N0f8}(0.467)  Gray{N0f8}(0.467)     Gray{N0f8}(0.459)  Gray{N0f8}(0.459)  Gray{N0f8}(0.459)  Gray{N0f8}(0.471)
#  Gray{N0f8}(0.471)  Gray{N0f8}(0.478)  Gray{N0f8}(0.471)  Gray{N0f8}(0.467)     Gray{N0f8}(0.447)  Gray{N0f8}(0.451)  Gray{N0f8}(0.463)  Gray{N0f8}(0.451)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.486)  Gray{N0f8}(0.467)  Gray{N0f8}(0.471)     Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.471)  Gray{N0f8}(0.459)
#  Gray{N0f8}(0.478)  Gray{N0f8}(0.482)  Gray{N0f8}(0.471)  Gray{N0f8}(0.471)  …  Gray{N0f8}(0.467)  Gray{N0f8}(0.459)  Gray{N0f8}(0.475)  Gray{N0f8}(0.475)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.471)  Gray{N0f8}(0.478)  Gray{N0f8}(0.471)     Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.471)  Gray{N0f8}(0.475)
#  Gray{N0f8}(0.478)  Gray{N0f8}(0.471)  Gray{N0f8}(0.463)  Gray{N0f8}(0.478)     Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.451)  Gray{N0f8}(0.478)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)  Gray{N0f8}(0.494)  Gray{N0f8}(0.478)     Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.467)  Gray{N0f8}(0.475)
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.482)  Gray{N0f8}(0.49)   Gray{N0f8}(0.494)     Gray{N0f8}(0.478)  Gray{N0f8}(0.475)  Gray{N0f8}(0.467)  Gray{N0f8}(0.475)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.482)  Gray{N0f8}(0.486)  Gray{N0f8}(0.49)   …  Gray{N0f8}(0.478)  Gray{N0f8}(0.478)  Gray{N0f8}(0.467)  Gray{N0f8}(0.463)
#  Gray{N0f8}(0.506)  Gray{N0f8}(0.478)  Gray{N0f8}(0.478)  Gray{N0f8}(0.49)      Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.459)  Gray{N0f8}(0.471)
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.498)  Gray{N0f8}(0.486)  Gray{N0f8}(0.478)     Gray{N0f8}(0.475)  Gray{N0f8}(0.451)  Gray{N0f8}(0.463)  Gray{N0f8}(0.486)
#  Gray{N0f8}(0.471)  Gray{N0f8}(0.49)   Gray{N0f8}(0.486)  Gray{N0f8}(0.486)     Gray{N0f8}(0.475)  Gray{N0f8}(0.463)  Gray{N0f8}(0.478)  Gray{N0f8}(0.471)
#  Gray{N0f8}(0.471)  Gray{N0f8}(0.502)  Gray{N0f8}(0.486)  Gray{N0f8}(0.478)     Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.482)  Gray{N0f8}(0.471)
#  Gray{N0f8}(0.478)  Gray{N0f8}(0.49)   Gray{N0f8}(0.486)  Gray{N0f8}(0.486)  …  Gray{N0f8}(0.475)  Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.467)
#  Gray{N0f8}(0.486)  Gray{N0f8}(0.498)  Gray{N0f8}(0.49)   Gray{N0f8}(0.486)     Gray{N0f8}(0.475)  Gray{N0f8}(0.463)  Gray{N0f8}(0.463)  Gray{N0f8}(0.467)
#  ⋮                                                                           ⋱                     ⋮
#  Gray{N0f8}(0.224)  Gray{N0f8}(0.271)  Gray{N0f8}(0.259)  Gray{N0f8}(0.243)  …  Gray{N0f8}(0.271)  Gray{N0f8}(0.255)  Gray{N0f8}(0.255)  Gray{N0f8}(0.255)
#  Gray{N0f8}(0.129)  Gray{N0f8}(0.18)   Gray{N0f8}(0.243)  Gray{N0f8}(0.255)     Gray{N0f8}(0.318)  Gray{N0f8}(0.337)  Gray{N0f8}(0.325)  Gray{N0f8}(0.286)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.145)  Gray{N0f8}(0.18)   Gray{N0f8}(0.231)     Gray{N0f8}(0.302)  Gray{N0f8}(0.302)  Gray{N0f8}(0.302)  Gray{N0f8}(0.298)
#  Gray{N0f8}(0.153)  Gray{N0f8}(0.165)  Gray{N0f8}(0.176)  Gray{N0f8}(0.231)     Gray{N0f8}(0.314)  Gray{N0f8}(0.318)  Gray{N0f8}(0.314)  Gray{N0f8}(0.314)
#  Gray{N0f8}(0.153)  Gray{N0f8}(0.184)  Gray{N0f8}(0.184)  Gray{N0f8}(0.255)     Gray{N0f8}(0.278)  Gray{N0f8}(0.267)  Gray{N0f8}(0.271)  Gray{N0f8}(0.278)
#  Gray{N0f8}(0.176)  Gray{N0f8}(0.153)  Gray{N0f8}(0.165)  Gray{N0f8}(0.231)  …  Gray{N0f8}(0.192)  Gray{N0f8}(0.188)  Gray{N0f8}(0.18)   Gray{N0f8}(0.18)
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.137)  Gray{N0f8}(0.125)  Gray{N0f8}(0.18)      Gray{N0f8}(0.227)  Gray{N0f8}(0.208)  Gray{N0f8}(0.196)  Gray{N0f8}(0.192)
#  Gray{N0f8}(0.129)  Gray{N0f8}(0.129)  Gray{N0f8}(0.165)  Gray{N0f8}(0.165)     Gray{N0f8}(0.271)  Gray{N0f8}(0.278)  Gray{N0f8}(0.282)  Gray{N0f8}(0.263)
#  Gray{N0f8}(0.133)  Gray{N0f8}(0.145)  Gray{N0f8}(0.153)  Gray{N0f8}(0.22)      Gray{N0f8}(0.263)  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)   Gray{N0f8}(0.208)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.235)  Gray{N0f8}(0.349)  Gray{N0f8}(0.514)     Gray{N0f8}(0.271)  Gray{N0f8}(0.231)  Gray{N0f8}(0.227)  Gray{N0f8}(0.263)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.482)  Gray{N0f8}(0.58)   Gray{N0f8}(0.49)   …  Gray{N0f8}(0.255)  Gray{N0f8}(0.278)  Gray{N0f8}(0.29)   Gray{N0f8}(0.29)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.537)  Gray{N0f8}(0.6)    Gray{N0f8}(0.608)     Gray{N0f8}(0.271)  Gray{N0f8}(0.286)  Gray{N0f8}(0.29)   Gray{N0f8}(0.275)
#  Gray{N0f8}(0.671)  Gray{N0f8}(0.761)  Gray{N0f8}(0.855)  Gray{N0f8}(0.761)     Gray{N0f8}(0.243)  Gray{N0f8}(0.243)  Gray{N0f8}(0.278)  Gray{N0f8}(0.302)
#  Gray{N0f8}(0.725)  Gray{N0f8}(0.702)  Gray{N0f8}(0.639)  Gray{N0f8}(0.557)     Gray{N0f8}(0.31)   Gray{N0f8}(0.298)  Gray{N0f8}(0.298)  Gray{N0f8}(0.302)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.451)  Gray{N0f8}(0.537)  Gray{N0f8}(0.675)     Gray{N0f8}(0.251)  Gray{N0f8}(0.224)  Gray{N0f8}(0.204)  Gray{N0f8}(0.212)
#  Gray{N0f8}(0.455)  Gray{N0f8}(0.455)  Gray{N0f8}(0.51)   Gray{N0f8}(0.553)  …  Gray{N0f8}(0.188)  Gray{N0f8}(0.196)  Gray{N0f8}(0.184)  Gray{N0f8}(0.2)
#  Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)       Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)    Gray{N0f8}(0.0)

# %% [markdown]
# ##### **Image Size and Singular Values**

# %%
# define matrix A to be the grayscale matrix
A = Float64.(gray);
print("shape of A: ", size(A), ",   type of A: ", typeof(A))
# Out:
# shape of A: (512, 768),   type of A: Matrix{Float64}

# %%
svdfactors = svd(Float64.(gray))
plot(  svdfactors.S, yscale=:log10, label="Singular Values (Gray)"  )

# %% [markdown]
# # 2. Approximate the Column Space $\mathscr{C}(A)$

# %% [markdown]
# ## 2.1 Random Vectors Tend to be Orthogonal

# %%
function dot_products_of_random_unit_vectors( vec_sz, num_vecs )
    Ω = randn(Float64, (vec_sz, num_vecs))
    for i in 1:num_vecs
        Ω[:,i] = Ω[:,i] / norm(Ω[:,i])   # Make cols of Ω have unit length
    end
    Ω'Ω
end
println( "Look at 50 vectors with increasing sizes: [10, 100, 1000]\n")
mosaicview( [ Gray.((x->1-x).(abs.(dot_products_of_random_unit_vectors( vec_sz, 50)))) for vec_sz in [10, 100, 1000]]..., nrow=1, npad=2 )
# Out:
# Look at 50 vectors with increasing sizes: [10, 100, 1000]
# 50×154 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)       Gray{Float64}(0.859096)  Gray{Float64}(0.680954)  …  Gray{Float64}(0.954123)  Gray{Float64}(0.962525)  Gray{Float64}(0.990149)
#  Gray{Float64}(0.859096)  Gray{Float64}(0.0)       Gray{Float64}(0.656176)     Gray{Float64}(0.961687)  Gray{Float64}(0.958032)  Gray{Float64}(0.962131)
#  Gray{Float64}(0.680954)  Gray{Float64}(0.656176)  Gray{Float64}(0.0)          Gray{Float64}(0.989214)  Gray{Float64}(0.973015)  Gray{Float64}(0.972298)
#  Gray{Float64}(0.870739)  Gray{Float64}(0.613419)  Gray{Float64}(0.654205)     Gray{Float64}(0.997707)  Gray{Float64}(0.986325)  Gray{Float64}(0.939978)
#  Gray{Float64}(0.772922)  Gray{Float64}(0.91714)   Gray{Float64}(0.550162)     Gray{Float64}(0.966852)  Gray{Float64}(0.929689)  Gray{Float64}(0.970912)
#  Gray{Float64}(0.802598)  Gray{Float64}(0.632072)  Gray{Float64}(0.702758)  …  Gray{Float64}(0.990787)  Gray{Float64}(0.987339)  Gray{Float64}(0.998304)
#  Gray{Float64}(0.870692)  Gray{Float64}(0.872975)  Gray{Float64}(0.913278)     Gray{Float64}(0.987634)  Gray{Float64}(0.983791)  Gray{Float64}(0.985169)
#  Gray{Float64}(0.994463)  Gray{Float64}(0.921021)  Gray{Float64}(0.943992)     Gray{Float64}(0.970034)  Gray{Float64}(0.960527)  Gray{Float64}(0.964139)
#  Gray{Float64}(0.863964)  Gray{Float64}(0.932965)  Gray{Float64}(0.913125)     Gray{Float64}(0.974111)  Gray{Float64}(0.9679)    Gray{Float64}(0.975198)
#  Gray{Float64}(0.836373)  Gray{Float64}(0.542343)  Gray{Float64}(0.852898)     Gray{Float64}(0.992603)  Gray{Float64}(0.958174)  Gray{Float64}(0.997915)
#  Gray{Float64}(0.566074)  Gray{Float64}(0.763526)  Gray{Float64}(0.677991)  …  Gray{Float64}(0.984818)  Gray{Float64}(0.957895)  Gray{Float64}(0.989096)
#  Gray{Float64}(0.803768)  Gray{Float64}(0.5324)    Gray{Float64}(0.350923)     Gray{Float64}(0.97741)   Gray{Float64}(0.990037)  Gray{Float64}(0.961135)
#  Gray{Float64}(0.562354)  Gray{Float64}(0.613373)  Gray{Float64}(0.964213)     Gray{Float64}(0.99125)   Gray{Float64}(0.984676)  Gray{Float64}(0.986458)
#  Gray{Float64}(0.54149)   Gray{Float64}(0.864255)  Gray{Float64}(0.831072)     Gray{Float64}(0.984445)  Gray{Float64}(0.973624)  Gray{Float64}(0.976256)
#  Gray{Float64}(0.785137)  Gray{Float64}(0.704007)  Gray{Float64}(0.870238)     Gray{Float64}(0.962223)  Gray{Float64}(0.99384)   Gray{Float64}(0.984047)
#  Gray{Float64}(0.857645)  Gray{Float64}(0.546128)  Gray{Float64}(0.596191)  …  Gray{Float64}(0.996044)  Gray{Float64}(0.931314)  Gray{Float64}(0.984597)
#  Gray{Float64}(0.419109)  Gray{Float64}(0.929403)  Gray{Float64}(0.96656)      Gray{Float64}(0.961533)  Gray{Float64}(0.962354)  Gray{Float64}(0.987686)
#  ⋮                                                                          ⋱
#  Gray{Float64}(0.785217)  Gray{Float64}(0.905586)  Gray{Float64}(0.752495)     Gray{Float64}(0.983336)  Gray{Float64}(0.950532)  Gray{Float64}(0.995838)
#  Gray{Float64}(0.857387)  Gray{Float64}(0.425587)  Gray{Float64}(0.797024)     Gray{Float64}(0.92535)   Gray{Float64}(0.99329)   Gray{Float64}(0.991916)
#  Gray{Float64}(0.703213)  Gray{Float64}(0.663982)  Gray{Float64}(0.774347)  …  Gray{Float64}(0.970934)  Gray{Float64}(0.9688)    Gray{Float64}(0.985307)
#  Gray{Float64}(0.600938)  Gray{Float64}(0.804119)  Gray{Float64}(0.66613)      Gray{Float64}(0.972797)  Gray{Float64}(0.98626)   Gray{Float64}(0.99179)
#  Gray{Float64}(0.831829)  Gray{Float64}(0.650182)  Gray{Float64}(0.522776)     Gray{Float64}(0.986845)  Gray{Float64}(0.983889)  Gray{Float64}(0.991042)
#  Gray{Float64}(0.872779)  Gray{Float64}(0.731951)  Gray{Float64}(0.856514)     Gray{Float64}(0.956244)  Gray{Float64}(0.983595)  Gray{Float64}(0.96777)
#  Gray{Float64}(0.630141)  Gray{Float64}(0.54279)   Gray{Float64}(0.686503)     Gray{Float64}(0.985786)  Gray{Float64}(0.986484)  Gray{Float64}(0.959929)
#  Gray{Float64}(0.363202)  Gray{Float64}(0.84882)   Gray{Float64}(0.801742)  …  Gray{Float64}(0.957563)  Gray{Float64}(0.97715)   Gray{Float64}(0.965221)
#  Gray{Float64}(0.518646)  Gray{Float64}(0.640722)  Gray{Float64}(0.960508)     Gray{Float64}(0.967073)  Gray{Float64}(0.971021)  Gray{Float64}(0.986394)
#  Gray{Float64}(0.841839)  Gray{Float64}(0.900344)  Gray{Float64}(0.75208)      Gray{Float64}(0.990571)  Gray{Float64}(0.982939)  Gray{Float64}(0.96275)
#  Gray{Float64}(0.498153)  Gray{Float64}(0.803044)  Gray{Float64}(0.674676)     Gray{Float64}(0.961947)  Gray{Float64}(0.987429)  Gray{Float64}(0.998038)
#  Gray{Float64}(0.804168)  Gray{Float64}(0.569571)  Gray{Float64}(0.544561)     Gray{Float64}(0.970047)  Gray{Float64}(0.985365)  Gray{Float64}(0.989819)
#  Gray{Float64}(0.605762)  Gray{Float64}(0.747915)  Gray{Float64}(0.497023)  …  Gray{Float64}(0.998948)  Gray{Float64}(0.988519)  Gray{Float64}(0.98217)
#  Gray{Float64}(0.69719)   Gray{Float64}(0.936398)  Gray{Float64}(0.659588)     Gray{Float64}(0.987868)  Gray{Float64}(0.959679)  Gray{Float64}(0.937229)
#  Gray{Float64}(0.691567)  Gray{Float64}(0.443221)  Gray{Float64}(0.636255)     Gray{Float64}(0.0)       Gray{Float64}(0.951212)  Gray{Float64}(0.99879)
#  Gray{Float64}(0.962114)  Gray{Float64}(0.555501)  Gray{Float64}(0.730486)     Gray{Float64}(0.951212)  Gray{Float64}(0.0)       Gray{Float64}(0.99365)
#  Gray{Float64}(0.76122)   Gray{Float64}(0.982894)  Gray{Float64}(0.680905)     Gray{Float64}(0.99879)   Gray{Float64}(0.99365)   Gray{Float64}(1.11022e-16)

# %% [markdown]
# ## 2.2 Random Samples of the Column Space

# %%
# Sample the column Space
#   take k linear combinations of random columns of A
#   perform QR and return Q (a basis for a subspace of Col(A) )
function approx_ColA( A, k )
    Aapprox = A * randn(Float64, (size(A,2), k))
    Matrix(qr(Aapprox).Q)
end;

# %% [markdown]
# Our `approx_ColA(A,n)` samples the column Space $\mathscr{C}(A)$ in roughly orthogonal directions<br>
# $\qquad$ use QR to orthogonalize the resulting samples: matrix $Q$
#
# Sizes:
# * $A$ is $M\times N$
# * $Q$ is $M \times K$, where we want $K << N$  (long and skinny)

# %% [markdown]
# **Remark:** $A$ does not have to be in memory at the same time!

# %% [markdown]
# What happens when we project $A$ onto $\mathscr{C}(Q)$, i.e., when we compute $Q Q^T A$

# %%
Aapprox_list = []
choice_of_K = [10,25,100]
for k in choice_of_K
    Q = approx_ColA( A, k)
    push!(Aapprox_list, Gray.(Q*Q'A) )   # project A onto Q
end
println( "Size A = ", size(A) )
println( "Sizes of Q = ", choice_of_K )
println()
mosaicview( Aapprox_list...; nrow=1)
# Out:
# Size A = (512, 768)
# Sizes of Q =
# [10, 25, 100]
# 512×2304 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.46695)   Gray{Float64}(0.467818)  Gray{Float64}(0.46791)   …  Gray{Float64}(0.434343)  Gray{Float64}(0.439426)  Gray{Float64}(0.44859)
#  Gray{Float64}(0.464136)  Gray{Float64}(0.464625)  Gray{Float64}(0.46461)      Gray{Float64}(0.47344)   Gray{Float64}(0.479316)  Gray{Float64}(0.476946)
#  Gray{Float64}(0.463725)  Gray{Float64}(0.465437)  Gray{Float64}(0.464334)     Gray{Float64}(0.469913)  Gray{Float64}(0.468326)  Gray{Float64}(0.468668)
#  Gray{Float64}(0.470717)  Gray{Float64}(0.472412)  Gray{Float64}(0.472185)     Gray{Float64}(0.452813)  Gray{Float64}(0.457119)  Gray{Float64}(0.463492)
#  Gray{Float64}(0.472874)  Gray{Float64}(0.47279)   Gray{Float64}(0.471644)     Gray{Float64}(0.455353)  Gray{Float64}(0.460384)  Gray{Float64}(0.466679)
#  Gray{Float64}(0.472203)  Gray{Float64}(0.472871)  Gray{Float64}(0.47185)   …  Gray{Float64}(0.457994)  Gray{Float64}(0.460148)  Gray{Float64}(0.470375)
#  Gray{Float64}(0.469348)  Gray{Float64}(0.469103)  Gray{Float64}(0.468243)     Gray{Float64}(0.466341)  Gray{Float64}(0.474605)  Gray{Float64}(0.47822)
#  Gray{Float64}(0.472129)  Gray{Float64}(0.472007)  Gray{Float64}(0.471066)     Gray{Float64}(0.469567)  Gray{Float64}(0.470276)  Gray{Float64}(0.465307)
#  Gray{Float64}(0.475223)  Gray{Float64}(0.476041)  Gray{Float64}(0.475429)     Gray{Float64}(0.467271)  Gray{Float64}(0.468718)  Gray{Float64}(0.468964)
#  Gray{Float64}(0.478033)  Gray{Float64}(0.478299)  Gray{Float64}(0.477484)     Gray{Float64}(0.453798)  Gray{Float64}(0.45746)   Gray{Float64}(0.461546)
#  Gray{Float64}(0.466484)  Gray{Float64}(0.466531)  Gray{Float64}(0.466804)  …  Gray{Float64}(0.469792)  Gray{Float64}(0.472064)  Gray{Float64}(0.471662)
#  Gray{Float64}(0.468258)  Gray{Float64}(0.469754)  Gray{Float64}(0.468955)     Gray{Float64}(0.468953)  Gray{Float64}(0.469313)  Gray{Float64}(0.47265)
#  Gray{Float64}(0.475297)  Gray{Float64}(0.47617)   Gray{Float64}(0.474046)     Gray{Float64}(0.466424)  Gray{Float64}(0.466114)  Gray{Float64}(0.46737)
#  Gray{Float64}(0.473987)  Gray{Float64}(0.474596)  Gray{Float64}(0.474469)     Gray{Float64}(0.468611)  Gray{Float64}(0.462544)  Gray{Float64}(0.468089)
#  Gray{Float64}(0.473013)  Gray{Float64}(0.474157)  Gray{Float64}(0.473458)     Gray{Float64}(0.457818)  Gray{Float64}(0.461773)  Gray{Float64}(0.470124)
#  Gray{Float64}(0.467187)  Gray{Float64}(0.467478)  Gray{Float64}(0.466849)  …  Gray{Float64}(0.461305)  Gray{Float64}(0.472012)  Gray{Float64}(0.477489)
#  Gray{Float64}(0.469371)  Gray{Float64}(0.46994)   Gray{Float64}(0.469682)     Gray{Float64}(0.464101)  Gray{Float64}(0.461195)  Gray{Float64}(0.464818)
#  ⋮                                                                          ⋱
#  Gray{Float64}(0.274325)  Gray{Float64}(0.262247)  Gray{Float64}(0.262174)  …  Gray{Float64}(0.268532)  Gray{Float64}(0.229114)  Gray{Float64}(0.176263)
#  Gray{Float64}(0.29248)   Gray{Float64}(0.282017)  Gray{Float64}(0.283427)     Gray{Float64}(0.214175)  Gray{Float64}(0.214269)  Gray{Float64}(0.155254)
#  Gray{Float64}(0.331314)  Gray{Float64}(0.327209)  Gray{Float64}(0.322688)     Gray{Float64}(0.170288)  Gray{Float64}(0.187952)  Gray{Float64}(0.202423)
#  Gray{Float64}(0.27357)   Gray{Float64}(0.261547)  Gray{Float64}(0.260785)     Gray{Float64}(0.346146)  Gray{Float64}(0.357347)  Gray{Float64}(0.40259)
#  Gray{Float64}(0.234955)  Gray{Float64}(0.221995)  Gray{Float64}(0.227229)     Gray{Float64}(0.253761)  Gray{Float64}(0.220167)  Gray{Float64}(0.242472)
#  Gray{Float64}(0.245661)  Gray{Float64}(0.238917)  Gray{Float64}(0.239899)  …  Gray{Float64}(0.179324)  Gray{Float64}(0.164546)  Gray{Float64}(0.135835)
#  Gray{Float64}(0.239441)  Gray{Float64}(0.23991)   Gray{Float64}(0.245364)     Gray{Float64}(0.270185)  Gray{Float64}(0.25875)   Gray{Float64}(0.238252)
#  Gray{Float64}(0.259136)  Gray{Float64}(0.25695)   Gray{Float64}(0.264995)     Gray{Float64}(0.288476)  Gray{Float64}(0.306196)  Gray{Float64}(0.285624)
#  Gray{Float64}(0.255759)  Gray{Float64}(0.252514)  Gray{Float64}(0.265682)     Gray{Float64}(0.251154)  Gray{Float64}(0.246106)  Gray{Float64}(0.283762)
#  Gray{Float64}(0.339013)  Gray{Float64}(0.340742)  Gray{Float64}(0.341126)     Gray{Float64}(0.29397)   Gray{Float64}(0.299499)  Gray{Float64}(0.302323)
#  Gray{Float64}(0.38844)   Gray{Float64}(0.388906)  Gray{Float64}(0.381527)  …  Gray{Float64}(0.253817)  Gray{Float64}(0.284626)  Gray{Float64}(0.273193)
#  Gray{Float64}(0.330487)  Gray{Float64}(0.351904)  Gray{Float64}(0.35785)      Gray{Float64}(0.235677)  Gray{Float64}(0.255783)  Gray{Float64}(0.310724)
#  Gray{Float64}(0.336436)  Gray{Float64}(0.363058)  Gray{Float64}(0.380331)     Gray{Float64}(0.222441)  Gray{Float64}(0.2296)    Gray{Float64}(0.262386)
#  Gray{Float64}(0.40994)   Gray{Float64}(0.421686)  Gray{Float64}(0.433841)     Gray{Float64}(0.28066)   Gray{Float64}(0.308629)  Gray{Float64}(0.28413)
#  Gray{Float64}(0.376255)  Gray{Float64}(0.384405)  Gray{Float64}(0.389085)     Gray{Float64}(0.275759)  Gray{Float64}(0.320407)  Gray{Float64}(0.339163)
#  Gray{Float64}(0.361884)  Gray{Float64}(0.371346)  Gray{Float64}(0.376672)  …  Gray{Float64}(0.159883)  Gray{Float64}(0.160646)  Gray{Float64}(0.1883)
#  Gray{Float64}(0.0)       Gray{Float64}(0.0)       Gray{Float64}(0.0)          Gray{Float64}(0.0)       Gray{Float64}(0.0)       Gray{Float64}(0.0)

# %%
mosaicview( [(x->1-x).(img-gray) for img in Aapprox_list]...; nrow=1)
# Out:
# 512×2304 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{Base.IdentityUnitRange{UnitRange{Int64}}, Base.IdentityUnitRange{UnitRange{Int64}}}, Matrix{Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.995795)  Gray{Float64}(0.983163)  Gray{Float64}(0.98307)   …  Gray{Float64}(0.993108)  Gray{Float64}(1.00763)   Gray{Float64}(1.00239)
#  Gray{Float64}(0.998609)  Gray{Float64}(1.00596)   Gray{Float64}(1.00206)      Gray{Float64}(0.985384)  Gray{Float64}(0.971664)  Gray{Float64}(0.993642)
#  Gray{Float64}(1.02255)   Gray{Float64}(0.997308)  Gray{Float64}(1.00233)      Gray{Float64}(0.988911)  Gray{Float64}(0.990497)  Gray{Float64}(1.00192)
#  Gray{Float64}(0.999871)  Gray{Float64}(1.00602)   Gray{Float64}(0.998404)     Gray{Float64}(0.998168)  Gray{Float64}(1.00563)   Gray{Float64}(0.987488)
#  Gray{Float64}(1.00164)   Gray{Float64}(1.01348)   Gray{Float64}(0.995023)     Gray{Float64}(1.00739)   Gray{Float64}(1.0102)    Gray{Float64}(0.992145)
#  Gray{Float64}(1.00623)   Gray{Float64}(1.00948)   Gray{Float64}(0.998739)  …  Gray{Float64}(1.00083)   Gray{Float64}(1.01436)   Gray{Float64}(1.00413)
#  Gray{Float64}(1.02085)   Gray{Float64}(1.00149)   Gray{Float64}(1.01019)      Gray{Float64}(0.996404)  Gray{Float64}(0.995983)  Gray{Float64}(0.99629)
#  Gray{Float64}(1.0063)    Gray{Float64}(0.998581)  Gray{Float64}(0.991679)     Gray{Float64}(0.993178)  Gray{Float64}(0.980704)  Gray{Float64}(1.01312)
#  Gray{Float64}(0.999286)  Gray{Float64}(1.00631)   Gray{Float64}(1.01869)      Gray{Float64}(0.995474)  Gray{Float64}(0.997948)  Gray{Float64}(1.00555)
#  Gray{Float64}(0.984712)  Gray{Float64}(1.00405)   Gray{Float64}(1.01271)      Gray{Float64}(1.02071)   Gray{Float64}(1.00921)   Gray{Float64}(1.01296)
#  Gray{Float64}(1.02371)   Gray{Float64}(1.01582)   Gray{Float64}(1.01947)   …  Gray{Float64}(1.00864)   Gray{Float64}(0.994603)  Gray{Float64}(0.991083)
#  Gray{Float64}(1.03762)   Gray{Float64}(1.00868)   Gray{Float64}(1.00948)      Gray{Float64}(0.993793)  Gray{Float64}(0.989511)  Gray{Float64}(0.997938)
#  Gray{Float64}(1.01882)   Gray{Float64}(1.02187)   Gray{Float64}(1.01223)      Gray{Float64}(0.984557)  Gray{Float64}(0.996631)  Gray{Float64}(1.01891)
#  Gray{Float64}(0.996601)  Gray{Float64}(1.0156)    Gray{Float64}(1.01181)      Gray{Float64}(0.994134)  Gray{Float64}(1.01589)   Gray{Float64}(1.0025)
#  Gray{Float64}(0.997575)  Gray{Float64}(1.0278)    Gray{Float64}(1.01282)      Gray{Float64}(1.00493)   Gray{Float64}(1.02058)   Gray{Float64}(1.00046)
#  Gray{Float64}(1.01124)   Gray{Float64}(1.02272)   Gray{Float64}(1.01943)   …  Gray{Float64}(1.00144)   Gray{Float64}(0.990734)  Gray{Float64}(0.989178)
#  Gray{Float64}(1.0169)    Gray{Float64}(1.0281)    Gray{Float64}(1.02051)      Gray{Float64}(0.998644)  Gray{Float64}(1.00155)   Gray{Float64}(1.00185)
#  ⋮                                                                          ⋱
#  Gray{Float64}(0.949205)  Gray{Float64}(1.00834)   Gray{Float64}(0.996649)  …  Gray{Float64}(0.98637)   Gray{Float64}(1.02579)   Gray{Float64}(1.07864)
#  Gray{Float64}(0.836932)  Gray{Float64}(0.898375)  Gray{Float64}(0.95971)      Gray{Float64}(1.12308)   Gray{Float64}(1.11122)   Gray{Float64}(1.13102)
#  Gray{Float64}(0.813784)  Gray{Float64}(0.817889)  Gray{Float64}(0.857704)     Gray{Float64}(1.13167)   Gray{Float64}(1.11401)   Gray{Float64}(1.09562)
#  Gray{Float64}(0.879371)  Gray{Float64}(0.903159)  Gray{Float64}(0.915686)     Gray{Float64}(0.971501)  Gray{Float64}(0.956379)  Gray{Float64}(0.911135)
#  Gray{Float64}(0.917986)  Gray{Float64}(0.962319)  Gray{Float64}(0.957084)     Gray{Float64}(1.01291)   Gray{Float64}(1.05042)   Gray{Float64}(1.03596)
#  Gray{Float64}(0.93081)   Gray{Float64}(0.914024)  Gray{Float64}(0.924807)  …  Gray{Float64}(1.00891)   Gray{Float64}(1.01585)   Gray{Float64}(1.04456)
#  Gray{Float64}(0.901735)  Gray{Float64}(0.897345)  Gray{Float64}(0.880126)     Gray{Float64}(0.937658)  Gray{Float64}(0.937329)  Gray{Float64}(0.953905)
#  Gray{Float64}(0.870276)  Gray{Float64}(0.872462)  Gray{Float64}(0.89971)      Gray{Float64}(0.989955)  Gray{Float64}(0.976157)  Gray{Float64}(0.977121)
#  Gray{Float64}(0.877575)  Gray{Float64}(0.892584)  Gray{Float64}(0.887259)     Gray{Float64}(0.968453)  Gray{Float64}(0.973501)  Gray{Float64}(0.924081)
#  Gray{Float64}(0.829615)  Gray{Float64}(0.894552)  Gray{Float64}(1.00789)      Gray{Float64}(0.937403)  Gray{Float64}(0.927952)  Gray{Float64}(0.960422)
#  Gray{Float64}(0.909599)  Gray{Float64}(1.09345)   Gray{Float64}(1.19886)   …  Gray{Float64}(1.02461)   Gray{Float64}(1.00557)   Gray{Float64}(1.017)
#  Gray{Float64}(1.15971)   Gray{Float64}(1.18535)   Gray{Float64}(1.24215)      Gray{Float64}(1.0506)    Gray{Float64}(1.03441)   Gray{Float64}(0.963786)
#  Gray{Float64}(1.33415)   Gray{Float64}(1.39773)   Gray{Float64}(1.47457)      Gray{Float64}(1.0207)    Gray{Float64}(1.04883)   Gray{Float64}(1.03958)
#  Gray{Float64}(1.31555)   Gray{Float64}(1.28028)   Gray{Float64}(1.20537)      Gray{Float64}(1.01738)   Gray{Float64}(0.98941)   Gray{Float64}(1.01783)
#  Gray{Float64}(1.09825)   Gray{Float64}(1.06658)   Gray{Float64}(1.14817)      Gray{Float64}(0.94777)   Gray{Float64}(0.883514)  Gray{Float64}(0.872602)
#  Gray{Float64}(1.09302)   Gray{Float64}(1.08356)   Gray{Float64}(1.13313)   …  Gray{Float64}(1.0362)    Gray{Float64}(1.02367)   Gray{Float64}(1.0117)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(1.0)       Gray{Float64}(1.0)       Gray{Float64}(1.0)

# %% [markdown]
# # 3. Matrix Factorizations

# %% [markdown]
# ____
# **Idea:** Approximate $A \approx Q Q^{t} A$, and apply matrix factorization algorithms to the much smaller $Q^T A$ rather than $A$.
# * $A\qquad$ is $M\times N$
# * $Q\qquad$ is $M\times K$, where $K << min(M,N)$
# * $Q^T A\quad$ is $K \times N$

# %% [markdown]
# Consider the SVD decomposition $A = U \Sigma V^T$.<br>
# $\quad$ Then $Q^T A = Q^T U \Sigma V^T = \tilde{U} \Sigma V^T,$<br>
# $\quad$ so that the SVD of $Q^T A$ and the SVD of $A$ are related:<br>
# * they have the same singular values $\Sigma$ and the same singular vectors in $V$.
# * the singular vectors $\tilde{U}$ of $Q^T A$ are related to the singular vectors $U$ of $A$ by
# $U = Q^T \tilde{U}$

# %% [markdown]
# # 4. Randomized SVD

# %% [markdown]
# Suppose we can find an orthogonal matrix $Q$ such that $A \approx Q Q^T A$,<br>
# we can use this approximation to compute an approximate matrix decomposition of $A$.
#
# Matrix Sizes:
# * Let $A$ have size $M \times N$
# * Let $Q$ have size $M \times K$, where $K < N$.
# * Then $Q^T A$ has size $K \times N$. potentially much smaller that the original matrix.
#
# * The $\tilde{U}$ matrix of our SVD has size $K \times K$. (The original matrix $U$ is $N \times N$
#
# How to choose $K$?  Usually, $K = rank(A) + l,$ where $l \approx 5$.

# %%
function randomized_svd(A; k=5, may_transpose = false)
    if may_transpose
        transpose = size(A,1) < size(A,2)
        if transpose A = A' end
    end

    Q   = approx_ColA( A, k )
    QtA = Q'A

    svd_QtA = svd( QtA )
    U       = Q * svd_QtA.U

    if may_transpose && transpose
        SVD( svd_QtA.V, svd_QtA.S, Matrix(U') )
    else
        SVD( U, svd_QtA.S, svd_QtA.V' )
    end
end
function svdErr( svdA, A )
    norm( svdA.U * diagm( svdA.S ) * svdA.Vt  - A )
end

K=100
println( "Matrix size:    ", size(A) )
println( ".  choice of K: ", K )
svdA  = randomized_svd(A'; k=K)
@show svdErr( svdA, A' );
# Out:
# Matrix size:    (512, 768)
# .  choice of K: 100
# svdErr(svdA, A') =
# 28.512432346088517

# %% [markdown]
# ## 4.1 Randomized SVD

# %% [markdown]
# ____
# **Idea:** Power $(A^T A)^p A$ changes the distribution of the singular values
#
# $  \begin{align} A = U \Sigma V^T \Rightarrow
# \left( A A^T \right)^p A &= \left( U \Sigma \Sigma^T U^T \right)^p \left( U \Sigma V^T \right) \\
# &= U_r \Sigma^{p+1}_r V^T_r
# \end{align}.$

# %%
svdA = svd(A)
plot(  svdA.S/svdA.S[1], yscale=:log10, label="p=0", ylim=(1e-20,10)  )
Z = A
for p in 1:5
    Z    = A * (A'Z)
    svdZ = svd(Z)
    plot!( svdZ.S / svdZ.S[1], yscale=:log10, label="p=$p"  )
end
title!( "Relative Singular Values (Grayscale Image)")

# %% [markdown]
# ## 4.2 Randomized SVD with Power

# %%
function approxCol_Ap( A, p, k)
    Aapprox = A * randn(Float64, (size(A,2), k))
    for n in 1:p
        Aapprox = A * ( A'Aapprox)    # Z = (A A.T)^p A v
    end
    Matrix(qr(Aapprox).Q)
end
function randomized_svd_Ap(A; p=3, k=5)
    Q   = approxCol_Ap( A, p, k )
    QtA = Q'A

    svd_QtA = svd( QtA )
    U       = Q * svd_QtA.U

    SVD( U, svd_QtA.S, svd_QtA.V' )
end

K=100
println( "Matrix size:    ", size(A) )
println( ".  choice of K: ", K )
println( ".  svdErr as a function of the power" )
err = [svdErr( randomized_svd_Ap(A'; p, k=K), A' ) for p in 0:10]
plot(err)
# Out:
# Matrix size:    (512, 768)
# .  choice of K: 100
# .  svdErr as a function of the power

# %% [markdown]
# https://www.youtube.com/watch?v=mQlzdDTRJpU
# https://www.youtube.com/watch?v=dyeSHiwntxY
