# %% [markdown]
# <p style="font-size:35px;color:blue;">Semester Part 2</p>

# %% [markdown]
# # 1. Projects

# %% [markdown]
# Notebooks for a 15 min presentation of a topic

# %% [markdown]
# 1. Projections
# 2. Applications of the Normal Equation
#     * Least Squares, Chebychev Sampling
#     * PCA
# 3. Computing eigenvalues/eigenvectors
#     * Power Method, Inverse Power Method
#     * QR based algorithms, Arnoldi
# 4. SVD applications
# 5. Numerical Methods
#     * Differential Equations
# 6. A topic of your choice
#     * e.g., computations with graphs

# %% [markdown]
# # 2. Take Home Exam(s)

# %% [markdown]
# I need a few more days to grade your take homes   :(
# 1. Part 1: 4/13
# 2. Part 2: 5/11

# %% [markdown]
# # 3. Determinants

# %% [markdown]
# * Wedge Product
# * Legendre Expansion
# * GE
# * Cramer's Rule
# * Closed form formula for the inverse

# %% [markdown]
# # 4. Eigenvectors/Eigenvalues

# %% [markdown]
# * Introduction
# * Charpoly, eigenspaces
# * Diagonalization
# * Complex Eigenvalues
