# %%
using LinearAlgebra
#include("LAcodes.jl");
#LAcodes.title( "<strong>Eigenvectors and Eigenvalues</strong>", sz=30, color="darkred", justify="center")

# %% [markdown]
# <div style="float:center;width:100%;text-align:center;"><strong style="height:100px;color:darkred;font-size:40px;">Eigenvectors and Eigenvalues</strong>
# </div>

# %% [markdown]
# # 1.Special Directions for  $\;y\ =\ A\ x$

# %% [markdown]
# ## 1.1 Introduction

# %% [markdown]
# Finite dimensional Vector Spaces have bases, but bases are not unique:<br>
# **can we find "good" bases to use?**
#
# > Good bases in the context of a linear transformation $y = A x,$<br>
# where the transformation maps $\mathbb{R}^n \longrightarrow \mathbb{R}^n.$
#
# Linear transformations have special directions!

# %% [markdown]
# ### 1.1.1 Examples

# %% [markdown]
# #### Orthogonal Projections

# %% [markdown]
# <div style="float:left"><img src="OrthogonalProjection.svg" width="400"></div>
# <div style="float:center">
# Consider the orthogonal projection $P$ into some plane:
#
# * if we start with a vector $x$ in the plane, $P x = x$.
# * if we start with a vector from the origin to a point $x$<br> orthogonal to the plane, $P x = 0$.
#
# **Both of these cases have the form $$\mathbf{P x = \lambda x},$$<br>where $\lambda=1$ and $\lambda=0$.**
# </div>

# %% [markdown]
# #### Reflection through a Plane

# %% [markdown]
# <div style="float:left"><img src="OrthogonalReflection.svg" width="400"></div>
# <div style="float:center">
# Consider the orthogonal Reflection $R$ through some plane:
#
# * if we start with a vector $R$ in the plane, $R x = 1 x$.
# * if we start with a vector from the origin to a point $x$<br> orthogonal to the plane, $R x = -1 x$.
#
# **Both of these cases have the form $$\mathbf{R x = \lambda x},$$<br>where $\lambda=1$ and $\lambda=-1$.**
# </div>

# %% [markdown]
# #### Rotation about an axis

# %% [markdown]
# <div style="float:left"><img src="Rotation.svg" width="400"></div>
# <div style="float:center">
# Consider the Rotation $R$ around an axis:
#
# * if we start with a vector $x$ on the axis, $R x = 1 x$.
# * if we start with a vector $x$ in a plane orthogonal to the plane, $R x = ?.$<br>
#   Note however that the resultant vector is in that plane, rotated by the angle in question.
#
# **We again have the form $$\mathbf{R x = \lambda x},$$**<br>**where $\lambda=1$ for the rotation about the axis.**
# </div>

# %% [markdown]
# #### Dilation

# %% [markdown]
# What special directions are associated with
# $$
# y = \begin{pmatrix} 2 & 0\\ 0 & 3 \end{pmatrix} x \ ?$$

# %% [markdown]
# #### Hyperplanes, not just "Special Directions"

# %% [markdown]
# **Remark:** Actually, we should speak about special hyperplanes rather than special directions!
#
# Go back and look at the geometry of the above examples:
# * We see that $A x = \lambda x \Rightarrow A (\alpha x) = \lambda \alpha x = \lambda ( \alpha x )$,<br>
# so any vector along the line defined by such a direction $x$ has this property.

# %% [markdown]
# * If $x_1, x_2$ form a basis for a plane with $A x_1 = \lambda x_1$, $A x_2 = \lambda x_2$,<br>
# the any vector in the plane $x = \alpha x_1 + \beta x_2$ has this property:
# $$\begin{align} \mathbf{A x} &= A (\alpha x_1 + \beta x_2)\\ & = \alpha A x_1 + \beta A x_2\\ & = \lambda ( \alpha x_1 + \beta x_2 ) \\ &  = \mathbf{\lambda x}\end{align}
# $$

# %% [markdown]
# ## 1.2 The Eigenvector Eigenvalue Problem

# %% [markdown]
# ### 1.2.1 Definition

# %% [markdown]
# <div style="background-color:#F2F5A9">
#
# **Definition:** Let $A$ be a matrix of size $N \times N$<br>
# $\quad$ A <span style="color:red;">non-zero vector</span> $x$ is an **eigenvector** of $A$ iff $A x = \lambda x$ for some
# scalar $\lambda.$
#
# $\quad$ Such a scalar is an **eigenvalue** of $A$, and any solution $(\lambda, x)$ for $A x = \lambda x$ is an **eigenpair** for $A$.
# </div>

# %% [markdown]
# **Remarks:**
# * $x=0$ is always a solution of $A x = \lambda x$.<br> There is no direction associated with the origin, however,<br>so this **trivial solution is not interesting.**
# * the german word ***eigen*** means ***proper,*** or ***characteristic***.

# %% [markdown]
# ### 1.2.2 Checking Potential Eigenvectors

# %% [markdown]
# To check whether a given vector $x$ is an eigenvector,<br>
# $\quad$ **compute $\tilde{x} = A x$
# and check whether $\tilde{x} = \lambda x$ for some constant $\lambda.$**

# %% [markdown]
# #### **Example**

# %% [markdown]
# > Let $A = \begin{pmatrix}14 &  31 & -45\\
#  -6 & -12 &  18\\
#   0 &  1  & -1\end{pmatrix}\quad$
#  and $\quad x_1=\begin{pmatrix}-3\\1\\0\end{pmatrix},\;
# x_2=\begin{pmatrix}3\\0\\1\end{pmatrix},\;
# x_3=\begin{pmatrix}-4\\3\\1\end{pmatrix},\;
# x_4=\begin{pmatrix}0\\0\\0\end{pmatrix}.\;
# x_5=\begin{pmatrix}1\\1\\1\end{pmatrix}.\;
# $

# %% [markdown]
# > * $\tilde{x}_1 = A x_1 = \begin{pmatrix}-11\\6\\1\end{pmatrix} = \lambda \begin{pmatrix} -3 \\1 \\ 0 \end{pmatrix}.\quad\quad\;$
# $\therefore x_1$ is not an eigenvector, since $\tilde{x_1} = \lambda x_1$ has no solution.

# %% [markdown]
# > * $\tilde{x}_2 = A x_2 = \begin{pmatrix}-3\\0\\-1\end{pmatrix} = \lambda \begin{pmatrix}3\\0\\1\end{pmatrix} = - x_2.\quad$
# $\therefore x_2$ is an eigenvector of $A$ with eigenvalue $\lambda_2=-1$.

# %% [markdown]
# > * $\tilde{x}_3 = A x_3 = \begin{pmatrix}-8\\6\\2\end{pmatrix} = \lambda \begin{pmatrix}-4\\3\\1\end{pmatrix} = 2 x_3.\quad$
# $\therefore x_3$ is an eigenvector of $A$ with eigenvalue $\lambda_3=2$.

# %% [markdown]
# > * We immediately exclude $x_4$: The zero vector is **not** an eigenvector by definition.

# %% [markdown]
# > * $\tilde{x}_5 = A x_5 = \begin{pmatrix} 0 \\ 0 \\ 0 \end{pmatrix} = \lambda \begin{pmatrix}1\\1\\1\end{pmatrix} = 0 x_5.\quad$
# $\therefore x_5$ is an eigenvector of $A$ with eigenvalue $\lambda_5=0$.

# %% [markdown]
# # 2. Solution of $A\ x\ =\ \lambda\ x$

# %% [markdown]
# ## 2.1 The Characteristic Polynomial

# %% [markdown]
# ### 2.1.1 Rewrite the Equation into a Familiar Form

# %% [markdown]
# #### **A Homogeneous Solution Problem**

# %% [markdown]
# $A x = \lambda x$ is a **new type of problem.**<br>
# $\quad$ Given a square matrix $A$, we want to **find eigenpairs.**
#
# We can **transform this problem** into a form that we know how to solve:
# $$
# \qquad A x = \lambda x \; \Leftrightarrow \; A x - \lambda \color{red}I x = 0 \; \Leftrightarrow (A - \lambda I) x = 0.
# $$
#
# $\quad$ If we knew $\lambda$, this would be a **homogeneous solution problem** $\color{red}{A_\lambda x = 0}$,<br>
# $\qquad$ where $\color{red}{A_\lambda = A - \lambda I}$.

# %% [markdown]
# ---
# The **key to solving this problem** is to remember that we want non-zero solutions $x$.
#
# $\quad$ Therefore, the square matrix $A_\lambda$ **must have free variables,** i.e., $det A_\lambda = 0$.

# %% [markdown]
# #### **Example**

# %% [markdown]
# > Look at
# $\quad A = \begin{pmatrix}1&2\\2&1\end{pmatrix} \Leftrightarrow A - \lambda I =  \begin{pmatrix}1-\lambda&2\\2&1-\lambda\end{pmatrix}$

# %% [markdown]
# > The determinant
# > $$\qquad\qquad
# \begin{align}
# \color{red}{det A_\lambda} & = \begin{vmatrix}1-\lambda&2\\2&1-\lambda\end{vmatrix}\\ & = (1-\lambda)^2 - 4 \\ &= \color{red}{\lambda^2 - 2 \lambda - 3}.\end{align},
# $$
# >
# > $\quad$ This is a polynomial of degree 2!

# %% [markdown]
# > Since we require $det A_\lambda = 0$, we have to find the roots of this polynomial,<br>
# $\quad$ i.e., the values $\lambda$ such that $\lambda^2 - 2 \lambda -3 = 0 \Leftrightarrow
# \color{red}{\lambda = 3, -1}.$

# %% [markdown]
# #### **General Case**

# %% [markdown]
# <div>
# <div style="float:left;margin-left:1cm;width:50%;">
# Remember the Leibniz formula for the determinant:
#
# $$\qquad\qquad
# det A = \sum_{j_1 j_2 \dots j_n}{ \epsilon_{j_1 j_2 \dots j_n}\; a_{1 j_1}\ a_{2 j_2} \dots\ a_{n j_n}},
# $$
#
# $\quad$ where $\epsilon_{j_1 j_2 \dots j_n}$ is a sign $1,-1$ or zero:<br>
# $\qquad$ the determinant is made up of all possible terms<br>
# $\qquad$ where we pick **one entry** $A_{i j}$<br>
# $\qquad$ **from each row and each column** in $A$.
# </div><div style="float:left;width:30%;">
#
# <br>
# $$\left| \begin{matrix}
#           \alpha_{1 1}  & \boxed{\alpha_{1 2}} & \alpha_{1 3}         &         \alpha_{1 4}  \\
#           \alpha_{2 1}  &        \alpha_{2 2}  & \alpha_{2 3}         & \boxed{ \alpha_{2 4}} \\
#    \boxed{\alpha_{3 1}} &        \alpha_{3 2}  & {\alpha_{3 3}}       &         \alpha_{3 4}  \\
#           \alpha_{4 1}  &        \alpha_{4 2}  & \boxed{\alpha_{4 3}} &         \alpha_{4 4}
# \end{matrix} \right|$$
# </div>
# </div>

# %% [markdown]
# ---
# What this means for $p(\lambda) = det( A - \lambda I )$ is
# * this **determinant multiplies out to a polynomial**
# * the **highest degree** for $\lambda$ results from the selecion of the diagonal terms
# (the terms containing $\lambda$), i.e.,<br>
# $\quad (a_{1 1} - \lambda)(a_{2 2} - \lambda) \dots (a_{n n} - \lambda).$
#
# Thus,  $\quad det (A - \lambda I) = (-1)^n \lambda^n + \dots,$
# $\quad$ **a polynomial of degree $\mathbf{n}.$**

# %% [markdown]
# ### 2.1.2 The Solution of the Eigenproblem

# %% [markdown]
# <div style="background-color:#F2F5A9">
#
# **Definition:** The **characteristic polynomial** of a square matrix $A_{n \times n}$<br>
# $\quad$is given by $p(\lambda) = det( A - \lambda I)$.
# </div>

# %% [markdown]
# **Remarks:**
# * The only non-zero solutions of $A x = \lambda x \Leftrightarrow (A - \lambda I) x = 0$ occur when<br>
# $\quad$ $\mathbf{\lambda}$ **is a root of** $\mathbf{p(\lambda) = det ( A - \lambda I )}$
# * Given such a root $\lambda$, the corresponding **eigenvectors**<br>
# $\quad$ are the **homogeneous solutions of** $\mathbf{A_\lambda\ x = 0}$, where $\mathbf{A_\lambda = A - \lambda I.}$

# %% [markdown]
# ### 2.1.3 Properties of Polynomials

# %% [markdown]
# **Properties of polynomials $p(\lambda)$ of degree $n$ with real coefficients.**
# * $p(\lambda)$ has **exactly $\mathbf{n}$ roots.** The roots are not necessarily distinct.

# %% [markdown]
# * If $p(\lambda)$ has roots $\lambda_1, \lambda_2, \dots \lambda_n$, then $\mathbf{p(\lambda)}$ **can be factored** as<br>
#  $$\qquad p(\lambda) = c ( \lambda - \lambda_1)(\lambda - \lambda_2) \dots (\lambda - \lambda_n),$$
#
# $\qquad\;\;$where $c$ is the coefficient of the $\lambda^n$ term of $p(\lambda)$.<br>
# $\qquad\quad\;\;$in our case, $c = (-1)^n$.
#
# > **$\quad\;\;$Example**: $$\qquad\qquad \begin{align}p(\lambda) &= -\lambda^{3} + 5 \, \lambda^{2} - 3 \, \lambda - 9 \\ &= -{\left(\lambda + 1\right)} {\left(\lambda - 3\right)}{\left(\lambda - 3\right)}\end{align}$$

# %% [markdown]
# * The **roots** of $p(\lambda)$ **can be complex**, but roots occur in **complex conjugate pairs**:
#     * if $\lambda = \lambda_{re} + i \lambda_{im}$ is a root,
#       then $\lambda = \lambda_{re} - i \lambda_{im}$ is also a root.
#     * if the root $\lambda = \lambda_{re} + i \lambda_{im}$ occurs $k$ times,
#       then $\lambda = \lambda_{re} - i \lambda_{im}$ occurs $k$ times.
#
#
# $\quad\;\;$**Example**:
# $$\qquad\qquad \begin{align} p(\lambda) &=
# -\lambda^{5} + 12\, \lambda^{4} - 56 \, \lambda^{3} + 120 \, \lambda^{2} - 100\, \lambda
# \\
# &= -{\left(\lambda - (3 + i)\right)}^{2}\ {\left(\lambda - (3 - i\right) )}^{2}\ \lambda
# \end{align}$$

# %% [markdown]
# * **Remarks:**
#     * **Factoring is hard:** for polynomials with degree greater than 4 there is no algebraic formula.
#     * For degrees 3 and 4, the formulae are complicated, and difficult numerically
#     * **Root finding algorithms** are iterative refinements producing approximate solutions

# %% [markdown]
# * Let $\lambda_1, \lambda_2, \dots \lambda_n$ be the $n$ roots of $p(\lambda).$ **The roots are not necessarily distinct.**<br>
# $\quad$ We will combine terms for the same root (see the previous example).

# %% [markdown]
# <div style="background-color:#F2F5A9">
#
# **Definition:**
# Suppose a polynomial of degree $n$ has $k$ distinct roots $\lambda_1, \lambda_2, \dots \lambda_k.$ Then
# $$\qquad p(\lambda) = c (\lambda - \lambda_1)^{\mathbf{m_1}} (\lambda - \lambda_2)^{\mathbf{m_2}} \dots (\lambda - \lambda_k)^{\mathbf{m_k}}$$<br>
# $\quad$ The powers $\mathbf{m_1, m_2, \dots m_k}$ are the **algebraic multiplicities** of the roots $\lambda_1, \lambda_2, \dots \lambda_k$ respectively.
# </div>
#
# **Remark:** The algebraic multiplicities **add up to the degree of the polynomial.**

# %% [markdown]
# ### 2.1.4 Trace and Determinant

# %% [markdown]
# There are two important consequences of the root decomposition of a characteristic polynomial:

# %% [markdown]
# #### **The Trace of a Matrix**

# %% [markdown]
# The $\lambda^{n-1}$ term: Look at the coefficient $\color{red}{\tau}$ in $$\qquad\qquad
# p(\lambda) =  (-1)^n\  \left( \lambda^n + \color{red}{\tau \lambda^{n-1}} + \dots \right)
# $$<br><br>
# $\quad$ It results from the diagonal term in the expansion of $det(A - \lambda I)$:
# $$\qquad\qquad
# \begin{align}
# \xi & = (a_{1 1} - \lambda)(a_{2 2} - \lambda) \dots (a_{n n} - \lambda) \\
#     & = (-1)^n  \left( \lambda^n - \sum_{i=1}^n{a_{i i}} \ \lambda^{n-1} + \dots \right)\\
# \end{align}
# $$

# %% [markdown]
# Now compare this to the expansion of the root decomposition of this polynomial:
# $$\qquad\qquad
# \begin{align}
# p(\lambda) &= (-1)^n (\lambda - \lambda_1)(\lambda - \lambda_2) \dots (\lambda - \lambda_n)\\
#            &= (-1)^n \left( \lambda^n - \sum_{i=1}^n{ \lambda_i} \ \lambda^n + \dots \right)
# \end{align}
# $$
#
# $\therefore\quad$ **the sum of the diagonal terms in $\mathbf A$** equals **the sum of $\color{red}{\text{ all } n}$ eigenvalues of $A$**.

# %% [markdown]
# <div style="background-color:#F2F5A9">
#
# **Definition:** The **trace** of a square matrix $A_{n \times n}$
# is the sum of the entries on the main diagonal.
# $$\qquad\qquad
# trace \left( A \right) = \sum_{i=1}^n{a_{i i}}.
# $$
#
# **Theorem:** Let $\lambda_1, \lambda_2, \dots \lambda_n$ be the (not necessarily distinct)
#     $n$ eigenvalues of a matrix $A_{n\times n}$. Then
#     $$\qquad\qquad
#     trace \left(A \right) = \sum_{i=1}^n{\lambda_{i}}.
#     $$
# </div>

# %% [markdown]
# #### **The Determinant of a Matrix**

# %% [markdown]
# Since $p(\lambda) = det(A - \lambda I)$,we see that $\quad \mathbf{p(0) = det A}$.
#
# Comparing this to the root decomposition of the polynomial, we see
# $$\qquad\qquad
# p(0) = (-1)^n(0-\lambda_1)(0-\lambda 2)\dots(0-\lambda_n) = \prod_{i=1}^n{\lambda_i}.$$

# %% [markdown]
# <div style="background-color:#F2F5A9">
#
# **Theorem:** Let $\lambda_1, \lambda_2, \dots \lambda_n$ be the (not necessarily distinct)
#     $n$ eigenvalues of a matrix $A_{n\times n}$. Then
#     $$\qquad\qquad
#     det A = \prod_{i=1}^n{\lambda_{i}}.
#     $$
# </div>
#
# **Remark:** Comparing further terms in the expansions of the characteristic polynomials<br>
# &ensp;&ensp;yields further relationships between the coefficients of the polynomial and the eigenvalues.<br>
# &ensp;&ensp;Of these, the determinant and the trace are the most useful.

# %% [markdown]
# **Remark:** This yields another entry in the invertible matrix theorem
#
# <div style="background-color:#F2F5A9">
#
# **Theorem:** Let $A_{n\times n}$ be a square matrix with (not necessarily distinct) eigenvalues
#     $\lambda_1, \lambda_2, \dots \lambda_n$.<br>
# $\quad$ $A^{-1}$ does **not exist** iff at least one eigenvalue, say $\lambda_i = 0.$
# </div>

# %% [markdown]
# ## 2.2 Eigenvector/Eigenvalue Computation Examples

# %% [markdown]
# ### 2.2.1 A Simple $2\times 2$ Example

# %% [markdown]
# Consider $A = \begin{pmatrix}  0 & 2 \\ -1 & 3\end{pmatrix}$

# %% [markdown]
# #### **Step 1:** Compute the eigenvalues, i.e., the roots of the characteristic polynomial.

# %% [markdown]
# $$
# \begin{align}
# \color{red}{p(\lambda)}\ &= \color{red}{ det( A - \lambda I )}\\
#            &= \begin{vmatrix}   -\lambda & 2 \\ -1 & 3-\lambda \end{vmatrix} \\
#            &= -\lambda ( 3-\lambda ) + 2\\
#            & =  \color{red}{\lambda^2 - 3 \lambda + 2}
# \end{align}
# $$

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The roots of $p(\lambda)$ are $\mathbf{\lambda=1,2}, \quad$ i.e., $ \color{red}{p(\lambda) = (\lambda -1)(\lambda - 2)}.$
#
# > **Trace Test:**<br>$\quad trace ( A ) = 3;\quad$Sum of the eigenvalues $\lambda_1+\lambda_2 = 3.\quad$ Success: they are equal.

# %% [markdown]
# #### **Step 2:** Compute bases for the eigenspaces.

# %% [markdown]
# ##### Case $\mathbf{\lambda = 1}:$

# %% [markdown]
# <div style="text-indent:0.7cm">
#
# $A_1 = A-I = \begin{pmatrix}  -1 & 2 \\ -1 & 2\end{pmatrix}
# \sim \begin{pmatrix}  -1 & 2 \\ 0 & 0\end{pmatrix}$.
#
# The nullspace $\mathscr{N}(A-I)$ has basis $\left\{ \begin{pmatrix} 2 \\ 1 \end{pmatrix}\ \right\}.$
# </div>

# %% [markdown]
# > **Remark:** The row echelon form of $A_\lambda \color{red}{\textbf{ must have a missing pivot!}}$.<br>
# If not, fix the error in the comutations!

# %% [markdown]
# ##### Case $\mathbf{\lambda = 2}:$

# %% [markdown]
# <div style="text-indent:0.7cm">
#
# $A_2 = A-2 I = \begin{pmatrix}  -2 & 2 \\ -1 & 1\end{pmatrix}
# \sim \begin{pmatrix}  -1 & 1 \\ 0 & 0\end{pmatrix}$.
#
# The nullspace $\mathscr{N}(A)$ has basis $\left\{ \begin{pmatrix} 1 \\ 1 \end{pmatrix}\ \right\}.$
# </div>

# %% [markdown]
# #### **Summary Table**

# %% [markdown]
# <div style="float:left"><img src="EigenExample_1.svg" width=200></div>
# <div style="float:center">
# <table border="1" cellpadding="0" cellspacing="0" style="border-collapse: collapse" width="250px">
# <tr>
#     <td height="19" width="50px">$\color{blue}\lambda$</td>
#     <td height="19" width="100px">1</td>
#     <td height="19" width="100px">2</td>
# </tr>
# <tr>
#     <td height="16" width="50px"><span  style="color:blue;">(m)</span></td>
#     <td height="16" width="100px"><span  style="justify:right;">(1)</span></td>
#     <td height="16" width="100px">(1)</td>
# </tr>
# <tr>
#     <td height="19" width="50px"><span  style="color:blue;">Basis for $E_\lambda$</span></td>
#     <td height="19" width="100px">$\;\begin{pmatrix} 2 \\ 1 \end{pmatrix}\;$</td>
#     <td height="19" width="100px">$\;\begin{pmatrix} 1 \\ 1 \end{pmatrix}\;$</td>
# </tr>
# </table>
# </div>

# %% [markdown]
# ### 2.2.2 A $3 \times 3$ Example

# %% [markdown]
# Consider $A = \begin{pmatrix}
# -18 & 0 & -180 \\
#   6 & 2 &   54 \\
#   2 & 0 &   20 \end{pmatrix}$

# %% [markdown]
# #### **Step 1:** Compute the eigenvalues, i.e., the roots of the characteristic polynomial.

# %% [markdown]
# $$
# \begin{align}
# \color{red}{p(\lambda)}\ &= \color{red}{ det( A - \lambda I )}\\
#            &= \begin{vmatrix}
# -18-\lambda & 0 & -180 \\
#   6 & 2-\lambda &   54 \\
#   2 & 0 &   20-\lambda \end{vmatrix} \\
#            &= (2 - \lambda)\ \left[\ (-18-\lambda)\ (20-\lambda) + 360 \ \right]\\
#            & =  \color{red}{-(\lambda-2)^2\ \lambda }
# \end{align}
# $$

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**The roots of $p(\lambda)$ are $\;\;\lambda=2,0\quad$ with algebraic multiplicities $m = 2,1$ respectively.**
#
# > **Trace Test:**<br>$\quad trace ( A ) = 4;\quad$Sum of the eigenvalues $\lambda_1+\lambda_2 +\lambda_3 = 4.\quad$ Success.

# %% [markdown]
# #### **Step 2:** Compute bases for the eigenspaces.

# %% [markdown]
# ##### Case $\mathbf{\lambda = 2}:$

# %% [markdown]
# <div style="text-indent:0.7cm">
#
# $A_2 = A-2 I = \begin{pmatrix}  -20 & 0 & -180 \\6 & 0 & 54 \\2 & 0 & 18\end{pmatrix}
# \sim \begin{pmatrix}  1 & 0 & 9 \\ 0 & 0 & 0 \\ 0 & 0 & 0 \end{pmatrix}$.
#
# The nullspace $\mathscr{N}(A-2I)$ has basis $\left\{ \begin{pmatrix} -9 \\ 0 \\ 1 \end{pmatrix},
# \  \begin{pmatrix} 0 \\ 1 \\ 0 \end{pmatrix} \right\}.$
# </div>

# %% [markdown]
# ##### Case $\mathbf{\lambda = 0}:$

# %% [markdown]
# <div style="text-indent:0.7cm">
#
# $A_0 = A-0 I = \begin{pmatrix}
# -18 & 0 & -180 \\
#   6 & 2 &   54 \\
#   2 & 0 &   20 \end{pmatrix}
# \sim \begin{pmatrix}  1 & 0 & 10 \\ 0 & 1 & -3 \\ 0 & 0 & 0\end{pmatrix}$.
#
# The nullspace $\mathscr{N}(A_0)$ has basis $\left\{ \begin{pmatrix} -1 \\ 3 \\ 1 \end{pmatrix}\ \right\}.$
# </div>

# %% [markdown]
# #### **Summary Table**

# %% [markdown]
# <div style="float:left;"><img src="EigenExample_2.png" width=500></div>
# <div style="float:center;">
# <table border="1" cellpadding="0" cellspacing="0" style="border-collapse: collapse" width="300px">
# <tr>
#     <td height="19" width="50px">$\color{blue}\lambda$</td>
#     <td height="19" width="150px">2</td>
#     <td height="19" width="100px">0</td>
# </tr>
# <tr>
#     <td height="16" width="50px"><span  style="color:blue;">(m)</span></td>
#     <td height="16" width="150px"><span  style="justify:right;">(2)</span></td>
#     <td height="16" width="100px">(1)</td>
# </tr>
# <tr>
#     <td height="19" width="50px"><span  style="color:blue;">Basis for $E_\lambda$</span></td>
#     <td height="19" width="150px">$\begin{pmatrix} -9 \\ 0 \\ 1 \end{pmatrix},
# \  \begin{pmatrix} 0 \\ 1 \\ 0 \end{pmatrix}$</td>
#     <td height="19" width="100px">$\;\begin{pmatrix} -1 \\ 3 \\ 1 \end{pmatrix}\;$</td>
# </tr>
# </table>
# </div>

# %% [markdown]
# # 3. Take Away

# %% [markdown]
# * Solution of the Eigenvector / Eigenvalue Problem $\mathbf{ A x = \lambda x}$<br><br>
#     * **Step 1:** Solve $det(A - \lambda I)$ for the eigenvalues<br>
#         <span style="color:red;">Check eigenvalues using the trace test!</span><br><br>
#     * **Step 2:** Find a basis for $\mathscr{N}(A-\lambda I)$or each distinct eigenvalue<br>
#         <span style="color:red;">There must be missing pivots!</span> Otherwise, fix your arithmetic.<br><br>
#     * **Summary:** Summarize results in a table. (We will build on it!)
